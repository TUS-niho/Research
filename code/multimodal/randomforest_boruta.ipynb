# %% [markdown]
# Boruta（表情&音声）

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import os
import re
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from scipy.stats import mode
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from boruta import BorutaPy

pd.options.display.max_rows = None
#1.------前処理------

#表情データの読み込みとdfに格納
folder_path = Path('../../../output_filtered_questions')


file_list = folder_path.glob('*.csv')

file_path_list = [str(p) for p in file_list]

df = pd.DataFrame(file_path_list, columns=['filepath'])

files_df = df
files_df['filename'] = df['filepath'].apply(lambda p: Path(p).name)
files_df['ID'] = files_df['filename'].str.extract(r'ID(\d+)')
files_df['ID'] = files_df['ID'].astype(int)

#患者の疾患有無
labels_df = pd.read_csv(r"C:\Users\robotics\proj\Research\code\voice\delirium.csv")
#患者と疾患有無を結合
file_with_labels_df = pd.merge(files_df, labels_df, on='ID', how='left')
file_with_labels_df.drop(columns=['Sex'], inplace=True)

#print(file_with_labels_df)

#学習・テストデータとなるファイルの分割
X_files = file_with_labels_df.drop(columns='Delirum', errors='ignore')
#print(X_files)
y_labels = file_with_labels_df.drop(columns=['filepath', 'filename', 'ID'], errors='ignore')
#rint(y_labels)

#層化５分割交差検証
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for fold, (train_index, test_index) in enumerate(skf.split(X_files, y_labels)):
    X_train_sort, X_test_sort = X_files.iloc[train_index], X_files.iloc[test_index]
    y_train_sort, y_test_sort = y_labels.iloc[train_index], y_labels.iloc[test_index]

    #2.------学習データを読み込み、質問ごとの最大値を計算------

    train_file_path = [f for f in X_train_sort['filepath']]
    #print(train_file_path)
    train_df = pd.DataFrame()
    for f, a in zip(train_file_path, y_train_sort['Delirium']):
        df_train_file = pd.read_csv(f)
        #print(df_train_file)
        #ファイル名とラベルの付与
        current_filename = os.path.basename(f)
        #ファイル名の数字部分を抽出
        number = re.findall(r'\d+', current_filename)
        #print(number)
        df_train_file['Delirium'] = a
        df_train_file['filenumber'] = number[0]
        #print(df_train_file)  
        
        #必要のない列の削除
        #label列にある空白の削除
        df_train_file['label'] = df_train_file['label'].astype(str).str.strip()
        
        #応答部分のAUだけを抽出
        df_train_sort_df = df_train_file[df_train_file['label'].str.match('^answer(10|[1-9])$', na=False)]
        confidence = df_train_sort_df['Confidence'] <= 0.90
        rows_to_delete = df_train_sort_df[confidence].index
        df_train_new_df = df_train_sort_df.drop(rows_to_delete)
        columns_to_extract = ["label"] + [col for col in df_train_new_df.columns if col.startswith("AU")] + ["Delirium", "filenumber"]
        df_train_final_df = df_train_new_df[columns_to_extract]

        #print(df_train_final_df)

        columns_to_AU = ["AU07", "AU11", "AU20"]

        #AU07, 11, 20の削除
        df_train_final_df = df_train_final_df.drop(columns=columns_to_AU, errors='ignore')
        #print(df_train_final_df)

        #数値型に変更
        #df_train_final_df['filename'] = pd.to_numeric(df_train_final_df['filename'], errors='coerce')
        #print(df_train_final_df)

        #質問ごとの最大値を計算
        df_train_max_df = df_train_final_df.groupby('label').max()
        df_train_max_df = df_train_max_df.reset_index(drop=True)
        #print(df_train_max_df)

        train_df = pd.concat([train_df, df_train_max_df], ignore_index=True)

    #print(train_df)

    #3.------テストデータを読み込み、質問ごとの最大値を計算------

    test_file_path = [f for f in X_test_sort['filepath']]
    #print(test_file_path)
    test_df = pd.DataFrame()
    test_file_lengths = []
    for f, a in zip(test_file_path, y_test_sort['Delirium']):
        df_test_file = pd.read_csv(f)
        #print(df_test_file)
        #ファイル名とラベルの付与
        current_filename = os.path.basename(f)
        #print(current_filename)
        df_test_file['Delirium'] = a
        df_test_file['filename'] = current_filename
        #print(df_test_file)  
        
        #必要のない列の削除
        #label列にある空白の削除
        df_test_file['label'] = df_test_file['label'].astype(str).str.strip()
        
        #応答部分のAUだけを抽出
        df_test_sort_df = df_test_file[df_test_file['label'].str.match('^answer(10|[1-9])$', na=False)]
        confidence = df_test_sort_df['Confidence'] <= 0.90
        rows_to_delete = df_test_sort_df[confidence].index
        df_test_new_df = df_test_sort_df.drop(rows_to_delete)
        columns_to_extract = ["label"] + [col for col in df_test_new_df.columns if col.startswith("AU")] + ["Delirium", "filename"]
        df_test_final_df = df_test_new_df[columns_to_extract]

        #print(df_test_final_df)

        columns_to_AU = ["AU07", "AU11", "AU20"]

        #AU07, 11, 20の削除
        df_test_final_df = df_test_final_df.drop(columns=columns_to_AU, errors='ignore')
        #print(df_test_final_df)

        #数値型に変更
        #df_test_final_df['filename'] = pd.to_numeric(df_test_final_df['filename'], errors='coerce')
        #print(df_test_final_df)

        #質問ごとの最大値を計算
        df_test_max_df = df_test_final_df.groupby('label').max()
        df_test_max_df = df_test_max_df.reset_index(drop=True)
        #print(df_test_max_df)
        
        test_file_lengths.append(len(df_test_max_df))

        test_df = pd.concat([test_df, df_test_max_df], ignore_index=True)

    #print(test_df)
    #print(test_file_lengths)

    #4.------グリッドサーチのための学習・検証データの用意とテストデータの用意------

    y_train_grid = train_df['Delirium']
    y_test_grid = test_df['Delirium']

    columns_to_delete = ['Delirium']
    columns_to_delete2 = ['Delirium', 'filename']

    X_train_grid = train_df.drop(columns=columns_to_delete, errors='ignore')
    X_test_grid = test_df.drop(columns=columns_to_delete2, errors='ignore')

    #print(X_train_boruta)

"""     #患者ごとに分割するための変数を用意し、学習データからfilenumberを削除
    patient_groups = X_train_grid['filenumber'].values
    X_train_boruta = X_train_grid.drop(columns=['filenumber']).copy()

    #Add.------学習データだけを使用してBorutaを実行------

    #Borutaの実行
    Rf_boruta = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
    feat_selector = BorutaPy(Rf_boruta, n_estimators='auto', verbose=2, random_state=1)
    feat_selector.fit(X_train_boruta, y_train_grid)
    X_train_model = X_train_boruta.loc[:, feat_selector.support_]
    X_test_model = X_test_grid.loc[:, feat_selector.support_]

    #Borutaで採用、削除した特徴量の確認
    feature_names = np.array(X_train_boruta.columns)
    dropped_features = feature_names[~feat_selector.support_]
    accepted_features = feature_names[feat_selector.support_]
    tentative_features = feature_names[feat_selector.support_weak_]

    print(f"削除前の特徴量数：{len(feature_names)}")
    print(f"削除された特徴量数：{len(dropped_features)}")
    print("削除された特徴量一覧")
    print(dropped_features)

    #5.------学習の準備(学習器と学習方法の設定)------

    #モデル・グリッドサーチの定義
    model = RandomForestClassifier(random_state=42)
    cv = GroupKFold(n_splits=5, shuffle=True, random_state=42)
    param_grid = {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 5, 10, 15],
        'min_samples_split': [2, 5, 10]
        }
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='accuracy', cv=cv, n_jobs=-1)

    #6.------グリッドサーチ------
    grid_search.fit(X_train_model, y_train_grid, groups=patient_groups)
    print(f"---fold{fold+1}---\n")
    print(f"最適なハイパーパラメータ：{grid_search.best_params_}")
    print(f"CVでのmax精度(Accuracy):{grid_search.best_score_:.4f}")

    #行と列の表示制限を解除（または十分に大きな値に設定）
    pd.set_option('display.max_rows', None)     # すべての行を表示
    pd.set_option('display.max_columns', None)  # すべての列を表示
    pd.set_option('display.width', 1000)        # 表示幅を広くする

    #結果をDataFrameに変換し表示
    results_df = pd.DataFrame(grid_search.cv_results_)

    print("--- グリッドサーチの全試行結果 ---")
    print(results_df)

    #表示設定を元に戻す (推奨)
    #グローバルな設定を元に戻し、他の処理に影響を与えないようにします
    pd.reset_option('display.max_rows')
    pd.reset_option('display.max_columns')
    pd.reset_option('display.width')


    #7.------テストデータでの性能評価------
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test_model)
    final_accuracy = accuracy_score(y_test_grid, y_pred)

    print(f"テストデータでの正解率: {final_accuracy:.4}\n")
    #print(y_pred)

    file_predictions = []
    start_idx = 0
    for length in test_file_lengths:
        end_idx = start_idx + length
        predictions_for_this_file = y_pred[start_idx:end_idx]
        majority_vote = mode(predictions_for_this_file)[0]
        file_predictions.append([majority_vote, start_idx, end_idx])
        start_idx = end_idx

    first_column_list = [item[0] for item in file_predictions]

    #print(first_column_list)

    y_test_files = X_test_sort['Delirium'].values

    #print(type(y_test_files))

    y_test_files_copy = X_test_sort

    y_test_files_copy = y_test_files_copy.assign(Predictions=first_column_list)

    print("各テストファイルごとの分類結果\n")
    print(y_test_files_copy.drop(columns=['filepath'], errors='ignore'))

    correct_files = np.sum(np.array(first_column_list) == y_test_files)
    total_files = len(X_test_sort)
    file_accuracy = correct_files/ total_files

    scores = []
    scores.append(file_accuracy)
    print("\n")
    print(f"正解率 (ファイル単位): {file_accuracy:.4f} ({correct_files}/{total_files} ファイル正解)\n")


    #8.------混同行列の作成------
    cm = confusion_matrix(y_test_files, first_column_list)
    cm_df = pd.DataFrame(cm, 
                        index=['正解: 0', '正解: 1'], 
                        columns=['予測: 0', '予測: 1'])

    print("混同行列:")
    print(cm_df)
    print("\n") # 見やすいように改行

    #特徴量の重要度を取得
    feature_names = X_train_model.columns.tolist()
        
    importances = best_model.feature_importances_

    #特徴量の名前と重要度をまとめたDataFrameを作成
    importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': importances
    })

    #重要度が高い順にソート
    sorted_importance_df = importance_df.sort_values(by='Importance', ascending=False)

    print(sorted_importance_df) """
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 52
#      47 #rint(y_labels)
#      48
#      49 #層化５分割交差検証
#      50 skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
# ---> 52 for fold, (train_index, test_index) in enumerate(skf.split(X_files, y_labels)):
#      53     X_train_sort, X_test_sort = X_files.iloc[train_index], X_files.iloc[test_index]
#      54     y_train_sort, y_test_sort = y_labels.iloc[train_index], y_labels.iloc[test_index]
#
# File c:\Users\robotics\proj\delirium\Lib\site-packages\sklearn\model_selection\_split.py:887, in StratifiedKFold.split(self, X, y, groups)
#     882 if groups is not None:
#     883     warnings.warn(
#     884         f"The groups parameter is ignored by {self.__class__.__name__}",
#     885         UserWarning,
#     886     )
# --> 887 y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
#     888 return super().split(X, y, groups)
#
# File c:\Users\robotics\proj\delirium\Lib\site-packages\sklearn\utils\validation.py:1128, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1126     n_samples = _num_samples(array)
#    1127     if n_samples < ensure_min_samples:
# -> 1128         raise ValueError(
#    1129             "Found array with %d sample(s) (shape=%s) while a"
#    1130             " minimum of %d is required%s."
#    1131             % (n_samples, array.shape, ensure_min_samples, context)
#    1132         )
#    1134 if ensure_min_features > 0 and array.ndim == 2:
#    1135     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required.

# %% [markdown]
# データの用意

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import os
import re
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from scipy.stats import mode
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from boruta import BorutaPy

pd.options.display.max_rows = None

#表情データの読み込みとdfに格納
folder_path = Path('../../output_filtered_questions')
voice_path = Path('../voice/voice_csv_20ms')

file_list = folder_path.glob('*.csv')
voice_list = voice_path.glob('*.csv')

file_path_list = [str(p) for p in file_list]
voice_path_list = [str(p) for p in voice_list]

df = pd.DataFrame(file_path_list, columns=['filepath'])
voice_df = pd.DataFrame(voice_path_list, columns=['voice_filepath'])
#print(voice_df)


files_df = df
files_df['voice'] = voice_df['voice_filepath']
files_df['filename'] = df['filepath'].apply(lambda p: Path(p).name)
files_df['ID'] = files_df['filename'].str.extract(r'ID(\d+)')
files_df['ID'] = files_df['ID'].astype(int)

#患者の疾患有無
labels_df = pd.read_csv(r"C:\Users\robotics\proj\Research\code\voice\delirium.csv")
#患者と疾患有無を結合
file_with_labels_df = pd.merge(files_df, labels_df, on='ID', how='left')
file_with_labels_df.drop(columns=['Sex'], inplace=True)

print(file_with_labels_df)

#学習・テストデータとなるファイルの分割
X_files = file_with_labels_df.drop(columns='Delirum', errors='ignore')
#print(X_files)
y_labels = file_with_labels_df.drop(columns=['filepath', 'voice', 'filename', 'ID'], errors='ignore')
#rint(y_labels)
# Out:
#                                              filepath  \
# 0   ..\..\output_filtered_questions\filtered_ID36.csv
# 1   ..\..\output_filtered_questions\filtered_ID37.csv
# 2   ..\..\output_filtered_questions\filtered_ID38.csv
# 3   ..\..\output_filtered_questions\filtered_ID39.csv
# 4   ..\..\output_filtered_questions\filtered_ID40.csv
# 5   ..\..\output_filtered_questions\filtered_ID41.csv
# 6   ..\..\output_filtered_questions\filtered_ID42.csv
# 7   ..\..\output_filtered_questions\filtered_ID43.csv
# 8   ..\..\output_filtered_questions\filtered_ID44.csv
# 9   ..\..\output_filtered_questions\filtered_ID45.csv
# 10  ..\..\output_filtered_questions\filtered_ID46.csv
# 11  ..\..\output_filtered_questions\filtered_ID47.csv
# 12  ..\..\output_filtered_questions\filtered_ID48.csv
# 13  ..\..\output_filtered_questions\filtered_ID49.csv
# 14  ..\..\output_filtered_questions\filtered_ID50.csv
# 15  ..\..\output_filtered_questions\filtered_ID51.csv
# 16  ..\..\output_filtered_questions\filtered_ID52.csv
# 17  ..\..\output_filtered_questions\filtered_ID53.csv
# 18  ..\..\output_filtered_questions\filtered_ID54.csv
# 19  ..\..\output_filtered_questions\filtered_ID55.csv
# 20  ..\..\output_filtered_questions\filtered_ID56.csv
# 21  ..\..\output_filtered_questions\filtered_ID57.csv
# 22  ..\..\output_filtered_questions\filtered_ID58.csv
# 23  ..\..\output_filtered_questions\filtered_ID59.csv
# 24  ..\..\output_filtered_questions\filtered_ID60.csv
# 25  ..\..\output_filtered_questions\filtered_ID61.csv
# 26  ..\..\output_filtered_questions\filtered_ID62.csv
# 27  ..\..\output_filtered_questions\filtered_ID63.csv
# 28  ..\..\output_filtered_questions\filtered_ID64.csv
# 29  ..\..\output_filtered_questions\filtered_ID65.csv
# 30  ..\..\output_filtered_questions\filtered_ID66.csv
# 31  ..\..\output_filtered_questions\filtered_ID67.csv
# 32  ..\..\output_filtered_questions\filtered_ID68.csv
# 33  ..\..\output_filtered_questions\filtered_ID69.csv
# 34  ..\..\output_filtered_questions\filtered_ID70.csv
# 35  ..\..\output_filtered_questions\filtered_ID71.csv
# 36  ..\..\output_filtered_questions\filtered_ID72.csv
# 37  ..\..\output_filtered_questions\filtered_ID73.csv
# 38  ..\..\output_filtered_questions\filtered_ID74.csv
# 39  ..\..\output_filtered_questions\filtered_ID75.csv
# 40  ..\..\output_filtered_questions\filtered_ID76.csv
# 41  ..\..\output_filtered_questions\filtered_ID77.csv
# 42  ..\..\output_filtered_questions\filtered_ID78.csv
# 43  ..\..\output_filtered_questions\filtered_ID79.csv
# 44  ..\..\output_filtered_questions\filtered_ID80.csv
# 45  ..\..\output_filtered_questions\filtered_ID81.csv
# 46  ..\..\output_filtered_questions\filtered_ID82.csv
# 47  ..\..\output_filtered_questions\filtered_ID83.csv
# 48  ..\..\output_filtered_questions\filtered_ID84.csv
# 49  ..\..\output_filtered_questions\filtered_ID85.csv
# 50  ..\..\output_filtered_questions\filtered_ID86.csv
# 51  ..\..\output_filtered_questions\filtered_ID87.csv
# 52  ..\..\output_filtered_questions\filtered_ID88.csv
# 53  ..\..\output_filtered_questions\filtered_ID89.csv
# 54  ..\..\output_filtered_questions\filtered_ID90.csv
# 55  ..\..\output_filtered_questions\filtered_ID91.csv
# 56  ..\..\output_filtered_questions\filtered_ID92.csv
# 57  ..\..\output_filtered_questions\filtered_ID93.csv
# 58  ..\..\output_filtered_questions\filtered_ID94.csv
#
#                                     voice           filename  ID  Delirium
# 0   ..\voice\voice_csv_20ms\ID36_20ms.csv  filtered_ID36.csv  36         0
# 1   ..\voice\voice_csv_20ms\ID37_20ms.csv  filtered_ID37.csv  37         0
# 2   ..\voice\voice_csv_20ms\ID38_20ms.csv  filtered_ID38.csv  38         0
# 3   ..\voice\voice_csv_20ms\ID39_20ms.csv  filtered_ID39.csv  39         0
# 4   ..\voice\voice_csv_20ms\ID40_20ms.csv  filtered_ID40.csv  40         0
# 5   ..\voice\voice_csv_20ms\ID41_20ms.csv  filtered_ID41.csv  41         0
# 6   ..\voice\voice_csv_20ms\ID42_20ms.csv  filtered_ID42.csv  42         0
# 7   ..\voice\voice_csv_20ms\ID43_20ms.csv  filtered_ID43.csv  43         1
# 8   ..\voice\voice_csv_20ms\ID44_20ms.csv  filtered_ID44.csv  44         1
# 9   ..\voice\voice_csv_20ms\ID45_20ms.csv  filtered_ID45.csv  45         0
# 10  ..\voice\voice_csv_20ms\ID46_20ms.csv  filtered_ID46.csv  46         1
# 11  ..\voice\voice_csv_20ms\ID47_20ms.csv  filtered_ID47.csv  47         0
# 12  ..\voice\voice_csv_20ms\ID48_20ms.csv  filtered_ID48.csv  48         1
# 13  ..\voice\voice_csv_20ms\ID49_20ms.csv  filtered_ID49.csv  49         0
# 14  ..\voice\voice_csv_20ms\ID50_20ms.csv  filtered_ID50.csv  50         0
# 15  ..\voice\voice_csv_20ms\ID51_20ms.csv  filtered_ID51.csv  51         0
# 16  ..\voice\voice_csv_20ms\ID52_20ms.csv  filtered_ID52.csv  52         0
# 17  ..\voice\voice_csv_20ms\ID53_20ms.csv  filtered_ID53.csv  53         0
# 18  ..\voice\voice_csv_20ms\ID54_20ms.csv  filtered_ID54.csv  54         1
# 19  ..\voice\voice_csv_20ms\ID55_20ms.csv  filtered_ID55.csv  55         0
# 20  ..\voice\voice_csv_20ms\ID56_20ms.csv  filtered_ID56.csv  56         1
# 21  ..\voice\voice_csv_20ms\ID57_20ms.csv  filtered_ID57.csv  57         1
# 22  ..\voice\voice_csv_20ms\ID58_20ms.csv  filtered_ID58.csv  58         0
# 23  ..\voice\voice_csv_20ms\ID59_20ms.csv  filtered_ID59.csv  59         0
# 24  ..\voice\voice_csv_20ms\ID60_20ms.csv  filtered_ID60.csv  60         0
# 25  ..\voice\voice_csv_20ms\ID61_20ms.csv  filtered_ID61.csv  61         0
# 26  ..\voice\voice_csv_20ms\ID62_20ms.csv  filtered_ID62.csv  62         0
# 27  ..\voice\voice_csv_20ms\ID63_20ms.csv  filtered_ID63.csv  63         1
# 28  ..\voice\voice_csv_20ms\ID64_20ms.csv  filtered_ID64.csv  64         0
# 29  ..\voice\voice_csv_20ms\ID65_20ms.csv  filtered_ID65.csv  65         1
# 30  ..\voice\voice_csv_20ms\ID66_20ms.csv  filtered_ID66.csv  66         0
# 31  ..\voice\voice_csv_20ms\ID67_20ms.csv  filtered_ID67.csv  67         0
# 32  ..\voice\voice_csv_20ms\ID68_20ms.csv  filtered_ID68.csv  68         0
# 33  ..\voice\voice_csv_20ms\ID69_20ms.csv  filtered_ID69.csv  69         1
# 34  ..\voice\voice_csv_20ms\ID70_20ms.csv  filtered_ID70.csv  70         1
# 35  ..\voice\voice_csv_20ms\ID71_20ms.csv  filtered_ID71.csv  71         1
# 36  ..\voice\voice_csv_20ms\ID72_20ms.csv  filtered_ID72.csv  72         1
# 37  ..\voice\voice_csv_20ms\ID73_20ms.csv  filtered_ID73.csv  73         0
# 38  ..\voice\voice_csv_20ms\ID74_20ms.csv  filtered_ID74.csv  74         1
# 39  ..\voice\voice_csv_20ms\ID75_20ms.csv  filtered_ID75.csv  75         1
# 40  ..\voice\voice_csv_20ms\ID76_20ms.csv  filtered_ID76.csv  76         1
# 41  ..\voice\voice_csv_20ms\ID77_20ms.csv  filtered_ID77.csv  77         0
# 42  ..\voice\voice_csv_20ms\ID78_20ms.csv  filtered_ID78.csv  78         1
# 43  ..\voice\voice_csv_20ms\ID79_20ms.csv  filtered_ID79.csv  79         1
# 44  ..\voice\voice_csv_20ms\ID80_20ms.csv  filtered_ID80.csv  80         1
# 45  ..\voice\voice_csv_20ms\ID81_20ms.csv  filtered_ID81.csv  81         1
# 46  ..\voice\voice_csv_20ms\ID82_20ms.csv  filtered_ID82.csv  82         1
# 47  ..\voice\voice_csv_20ms\ID83_20ms.csv  filtered_ID83.csv  83         1
# 48  ..\voice\voice_csv_20ms\ID84_20ms.csv  filtered_ID84.csv  84         1
# 49  ..\voice\voice_csv_20ms\ID85_20ms.csv  filtered_ID85.csv  85         1
# 50  ..\voice\voice_csv_20ms\ID86_20ms.csv  filtered_ID86.csv  86         1
# 51  ..\voice\voice_csv_20ms\ID87_20ms.csv  filtered_ID87.csv  87         1
# 52  ..\voice\voice_csv_20ms\ID88_20ms.csv  filtered_ID88.csv  88         0
# 53  ..\voice\voice_csv_20ms\ID89_20ms.csv  filtered_ID89.csv  89         0
# 54  ..\voice\voice_csv_20ms\ID90_20ms.csv  filtered_ID90.csv  90         1
# 55  ..\voice\voice_csv_20ms\ID91_20ms.csv  filtered_ID91.csv  91         1
# 56  ..\voice\voice_csv_20ms\ID92_20ms.csv  filtered_ID92.csv  92         1
# 57  ..\voice\voice_csv_20ms\ID93_20ms.csv  filtered_ID93.csv  93         1
# 58  ..\voice\voice_csv_20ms\ID94_20ms.csv  filtered_ID94.csv  94         1

# %% [markdown]
# ランダムフォレスト

# %%
#層化５分割交差検証
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for fold, (train_index, test_index) in enumerate(skf.split(X_files, y_labels)):
    X_train_sort, X_test_sort = X_files.iloc[train_index], X_files.iloc[test_index]
    y_train_sort, y_test_sort = y_labels.iloc[train_index], y_labels.iloc[test_index]

    #2.------学習データを読み込み、質問ごとの最大値を計算------

    train_file_path = [f for f in X_train_sort['filepath']]
    train_voice_path = [v for v in X_train_sort['voice']]
    #print(train_file_path)
    train_df = pd.DataFrame()
    for f, v, a in zip(train_file_path, train_voice_path, y_train_sort['Delirium']):
        df_train_file = pd.read_csv(f)
        df_train_voice = pd.read_csv(v)
        #print(df_train_file)
        #ファイル名とラベルの付与
        current_filename = os.path.basename(f)
        #ファイル名の数字部分を抽出
        number = re.findall(r'\d+', current_filename)
        #print(number)
        df_train_file['Delirium'] = a
        df_train_file['filenumber'] = number[0]
        #print(df_train_file)  
        
        #必要のない列の削除
        #label列にある空白の削除
        df_train_file['label'] = df_train_file['label'].astype(str).str.strip()
        df_train_voice['label'] = df_train_voice['label'].str.strip()
        
        #応答部分のAUだけを抽出
        df_train_sort_df = df_train_file[df_train_file['label'].str.match('^answer(10|[1-9])$', na=False)]
        df_train_sort = (
            df_train_sort_df.groupby("label", group_keys=False, as_index=False, observed=True)
            .head(30)
            .reset_index(drop=True)
        )
        confidence = df_train_sort['Confidence'] <= 0.90
        rows_to_delete = df_train_sort[confidence].index
        df_train_new_df = df_train_sort.drop(rows_to_delete)
        columns_to_extract = ["label"] + [col for col in df_train_new_df.columns if col.startswith("AU")] + ["Delirium", "filenumber"]
        df_train_final_df = df_train_new_df[columns_to_extract]

        df_train_voice_df = df_train_voice[df_train_voice['label'].str.match('^answer(10|[1-9])$', na=False)]
        df_train_voice_drop = df_train_voice_df.dropna()

        #print(df_train_final_df)

        columns_to_AU = ["AU07", "AU11", "AU20"]
        columns_to_voice = ["start", "end", "Loudness_sma3", "alphaRatio_sma3", "hammarbergIndex_sma3", 
                            "slope0-500_sma3", "slope500-1500_sma3",  "logRelF0-H1-H2_sma3nz", "logRelF0-H1-A3_sma3nz", 
                            "F0semitoneFrom27.5Hz_sma3nz", "F1frequency_sma3nz", "F1bandwidth_sma3nz", "F1amplitudeLogRelF0_sma3nz",
                            "F2frequency_sma3nz", "F2bandwidth_sma3nz", "F2amplitudeLogRelF0_sma3nz",
                            "F3frequency_sma3nz", "F3bandwidth_sma3nz", "F3amplitudeLogRelF0_sma3nz",
                            "original_start", "original_end"]
        # "mfcc1_sma3", "mfcc2_sma3", "mfcc3_sma3", "mfcc4_sma3",
        #AU07, 11, 20の削除
        df_train_final_df = df_train_final_df.drop(columns=columns_to_AU, errors='ignore')
        df_train_voice_data = df_train_voice_drop.drop(columns=columns_to_voice, errors='ignore')
        #print(df_train_final_df)
        #print(df_train_voice_data)

        #数値型に変更
        #df_train_final_df['filename'] = pd.to_numeric(df_train_final_df['filename'], errors='coerce')
        #print(df_train_final_df)

        #質問ごとの最大値を計算
        df_train_max_df = df_train_final_df.groupby('label').max()
        df_train_max_df = df_train_max_df.reset_index(drop=True)

        df_train_max_voice = df_train_voice_data.groupby('label').max()
        df_train_max_voice = df_train_max_voice.reset_index(drop=True)
        #print(df_train_max_df)
        #print(df_train_max_voice)
        df_train_multi_df = pd.concat([df_train_max_df, df_train_max_voice], axis=1)
        
        train_df = pd.concat([train_df, df_train_multi_df], ignore_index=True)

        train_df = train_df.dropna()

    #print(train_df.columns)

    #3.------テストデータを読み込み、質問ごとの最大値を計算------

    test_file_path = [f for f in X_test_sort['filepath']]
    test_voice_path = [v for v in X_test_sort['voice']]
    #print(test_file_path)
    test_df = pd.DataFrame()
    test_file_lengths = []
    for f, v, a in zip(test_file_path, test_voice_path, y_test_sort['Delirium']):
        df_test_file = pd.read_csv(f)
        df_test_voice = pd.read_csv(v)
        #print(df_test_file)
        #ファイル名とラベルの付与
        current_filename = os.path.basename(f)
        #print(current_filename)
        df_test_file['Delirium'] = a
        df_test_file['filename'] = current_filename
        #print(df_test_file)  
        
        #必要のない列の削除
        #label列にある空白の削除
        df_test_file['label'] = df_test_file['label'].astype(str).str.strip()
        df_test_voice['label'] = df_test_voice['label'].str.strip()
        
        #応答部分のAUだけを抽出
        df_test_sort_df = df_test_file[df_test_file['label'].str.match('^answer(10|[1-9])$', na=False)]
        df_test_sort = (
            df_test_sort_df.groupby("label", group_keys=False, as_index=False, observed=True)
            .head(30)
            .reset_index(drop=True)
        )
        confidence = df_test_sort['Confidence'] <= 0.90
        rows_to_delete = df_test_sort[confidence].index
        df_test_new_df = df_test_sort.drop(rows_to_delete)
        columns_to_extract = ["label"] + [col for col in df_test_new_df.columns if col.startswith("AU")] + ["Delirium", "filename"]
        df_test_final_df = df_test_new_df[columns_to_extract]

        df_test_voice_df = df_test_voice[df_test_voice['label'].str.match('^answer(10|[1-9])$', na=False)]
        df_test_voice_drop = df_test_voice_df.dropna()

        #print(df_test_final_df)

        columns_to_AU = ["AU07", "AU11", "AU20"]
        columns_to_voice = ["start", "end", "Loudness_sma3", "alphaRatio_sma3", "hammarbergIndex_sma3", 
                            "slope0-500_sma3", "slope500-1500_sma3",  "logRelF0-H1-H2_sma3nz", "logRelF0-H1-A3_sma3nz", 
                            "F0semitoneFrom27.5Hz_sma3nz", "F1frequency_sma3nz", "F1bandwidth_sma3nz", "F1amplitudeLogRelF0_sma3nz",
                            "F2frequency_sma3nz", "F2bandwidth_sma3nz", "F2amplitudeLogRelF0_sma3nz",
                            "F3frequency_sma3nz", "F3bandwidth_sma3nz", "F3amplitudeLogRelF0_sma3nz",
                            "original_start", "original_end"]
        #"mfcc1_sma3", "mfcc2_sma3", "mfcc3_sma3", "mfcc4_sma3",
        #AU07, 11, 20の削除
        df_test_final_df = df_test_final_df.drop(columns=columns_to_AU, errors='ignore')
        df_test_voice_data = df_test_voice_drop.drop(columns=columns_to_voice, errors='ignore')
        #print(df_test_final_df)

        #数値型に変更
        #df_test_final_df['filename'] = pd.to_numeric(df_test_final_df['filename'], errors='coerce')
        #print(df_test_final_df)

        #質問ごとの最大値を計算
        df_test_max_df = df_test_final_df.groupby('label').max()
        df_test_max_df = df_test_max_df.reset_index(drop=True)

        df_test_max_voice = df_test_voice_data.groupby('label').mean()
        df_test_max_voice = df_test_max_voice.reset_index(drop=True)
        #print(df_test_max_df)
        #print(df_test_max_voice)
        
        test_file_lengths.append(len(df_test_max_df))

        df_test_multi_df = pd.concat([df_test_max_df, df_test_max_voice], axis=1)

        test_df = pd.concat([test_df, df_test_multi_df], ignore_index=True)

        test_df = test_df.dropna()

    print(test_df)
    #print(test_file_lengths)

    #4.------グリッドサーチのための学習・検証データの用意とテストデータの用意------

    y_train_grid = train_df['Delirium']
    y_test_grid = test_df['Delirium']

    columns_to_delete = ['Delirium']
    columns_to_delete2 = ['Delirium', 'filename']

    X_train_grid = train_df.drop(columns=columns_to_delete, errors='ignore')
    X_test_grid = test_df.drop(columns=columns_to_delete2, errors='ignore')

    #print(y_train_grid)

    #患者ごとに分割するための変数を用意し、学習データからfilenumberを削除
    patient_groups = X_train_grid['filenumber'].values
    X_train_boruta = X_train_grid.drop(columns=['filenumber']).copy()

    #Add.------学習データだけを使用してBorutaを実行------

    #Borutaの実行
    Rf_boruta = RandomForestClassifier(n_jobs=-1, max_depth=5)
    feat_selector = BorutaPy(Rf_boruta, n_estimators='auto', verbose=2, random_state=1, perc=80)
    feat_selector.fit(X_train_boruta, y_train_grid)
    X_train_model = X_train_boruta.loc[:, feat_selector.support_]
    X_test_model = X_test_grid.loc[:, feat_selector.support_]

    #Borutaで採用、削除した特徴量の確認
    feature_names = np.array(X_train_boruta.columns)
    dropped_features = feature_names[~feat_selector.support_]
    accepted_features = feature_names[feat_selector.support_]
    tentative_features = feature_names[feat_selector.support_weak_]

    print(f"削除前の特徴量数：{len(feature_names)}")
    print(f"削除された特徴量数：{len(dropped_features)}")
    print("削除された特徴量一覧")
    print(dropped_features)

    #5.------学習の準備(学習器と学習方法の設定)------

    #モデル・グリッドサーチの定義
    model = RandomForestClassifier(random_state=42)
    cv = GroupKFold(n_splits=5, shuffle=True, random_state=42)
    param_grid = {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 5, 10, 15],
        'min_samples_split': [2, 5, 10]
        }
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='accuracy', cv=cv, n_jobs=-1)

    #6.------グリッドサーチ------
    grid_search.fit(X_train_model, y_train_grid, groups=patient_groups)
    print(f"---fold{fold+1}---\n")
    print(f"最適なハイパーパラメータ：{grid_search.best_params_}")
    print(f"CVでのmax精度(Accuracy):{grid_search.best_score_:.4f}")

    #行と列の表示制限を解除（または十分に大きな値に設定）
    pd.set_option('display.max_rows', None)     # すべての行を表示
    pd.set_option('display.max_columns', None)  # すべての列を表示
    pd.set_option('display.width', 1000)        # 表示幅を広くする

    #結果をDataFrameに変換し表示
    results_df = pd.DataFrame(grid_search.cv_results_)

    print("--- グリッドサーチの全試行結果 ---")
    print(results_df)

    #表示設定を元に戻す (推奨)
    #グローバルな設定を元に戻し、他の処理に影響を与えないようにします
    pd.reset_option('display.max_rows')
    pd.reset_option('display.max_columns')
    pd.reset_option('display.width')


    #7.------テストデータでの性能評価------
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test_model)
    final_accuracy = accuracy_score(y_test_grid, y_pred)

    print(f"テストデータでの正解率: {final_accuracy:.4}\n")
    #print(y_pred)

    file_predictions = []
    start_idx = 0
    for length in test_file_lengths:
        end_idx = start_idx + length
        predictions_for_this_file = y_pred[start_idx:end_idx]
        majority_vote = mode(predictions_for_this_file)[0]
        file_predictions.append([majority_vote, start_idx, end_idx])
        start_idx = end_idx

    first_column_list = [item[0] for item in file_predictions]

    #print(first_column_list)

    y_test_files = X_test_sort['Delirium'].values

    #print(type(y_test_files))

    y_test_files_copy = X_test_sort

    y_test_files_copy = y_test_files_copy.assign(Predictions=first_column_list)

    print("各テストファイルごとの分類結果\n")
    print(y_test_files_copy.drop(columns=['filepath'], errors='ignore'))

    correct_files = np.sum(np.array(first_column_list) == y_test_files)
    total_files = len(X_test_sort)
    file_accuracy = correct_files/ total_files

    scores = []
    scores.append(file_accuracy)
    print("\n")
    print(f"正解率 (ファイル単位): {file_accuracy:.4f} ({correct_files}/{total_files} ファイル正解)\n")


    #8.------混同行列の作成------
    cm = confusion_matrix(y_test_files, first_column_list)
    cm_df = pd.DataFrame(cm, 
                        index=['正解: 0', '正解: 1'], 
                        columns=['予測: 0', '予測: 1'])

    print("混同行列:")
    print(cm_df)
    print("\n") # 見やすいように改行

    #特徴量の重要度を取得 """
    feature_names = X_train_model.columns.tolist()
        
    importances = best_model.feature_importances_

    #特徴量の名前と重要度をまとめたDataFrameを作成
    importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': importances
    
# 3    0.386509  0.498999  0.766122  ...       0.0  filtered_ID40.csv
# 4    0.320897  0.661873  0.234919  ...       0.0  filtered_ID40.csv
# 5    0.576703  0.636078  0.555233  ...       0.0  filtered_ID40.csv
# 6    0.133302  0.570290  0.817851  ...       0.0  filtered_ID40.csv
# 7    0.575583  0.568543  0.712569  ...       0.0  filtered_ID40.csv
# 8    0.947313  0.634584  0.814310  ...       0.0  filtered_ID40.csv
# 9    0.295218  0.587033  0.383082  ...       0.0  filtered_ID40.csv
# 10   0.032459  0.690006  0.919160  ...       1.0  filtered_ID43.csv
# 11   0.025601  0.707523  0.943877  ...       1.0  filtered_ID43.csv
# 12   0.021691  0.725176  0.930542  ...       1.0  filtered_ID43.csv
# 13   0.039842  0.753680  0.613891  ...       1.0  filtered_ID43.csv
# 14   0.051393  0.754106  0.829259  ...       1.0  filtered_ID43.csv
# 15   0.023300  0.756894  0.886349  ...       1.0  filtered_ID43.csv
# 16   0.022808  0.779916  0.948933  ...       1.0  filtered_ID43.csv
# 17   0.020682  0.794882  0.911970  ...       1.0  filtered_ID43.csv
# 18   0.020193  0.589325  0.956129  ...       1.0  filtered_ID43.csv
# 19   0.048301  0.764347  0.973312  ...       1.0  filtered_ID43.csv
# 20   0.130956  0.452419  0.827085  ...       1.0  filtered_ID44.csv
# 21   0.062923  0.301282  0.716078  ...       1.0  filtered_ID44.csv
# 22   0.073883  0.297382  0.653926  ...       1.0  filtered_ID44.csv
# 23   0.113061  0.257370  0.683529  ...       1.0  filtered_ID44.csv
# 24   0.246468  0.615509  0.874921  ...       1.0  filtered_ID44.csv
# 25   0.149527  0.461334  0.844642  ...       1.0  filtered_ID44.csv
# 26   0.132712  0.413061  0.804477  ...       1.0  filtered_ID44.csv
# 27   0.069850  0.435935  0.680974  ...       1.0  filtered_ID44.csv
# 28   0.113806  0.366070  0.714431  ...       1.0  filtered_ID44.csv
# 29   0.241516  0.649901  0.745771  ...       0.0  filtered_ID51.csv
# 30   0.105976  0.313529  0.746183  ...       0.0  filtered_ID51.csv
# 31   0.277658  0.489900  0.693823  ...       0.0  filtered_ID51.csv
# 32   0.250999  0.595340  0.714376  ...       0.0  filtered_ID51.csv
# 33   0.123122  0.450704  0.754580  ...       0.0  filtered_ID51.csv
# 34   0.133968  0.437044  0.921597  ...       0.0  filtered_ID51.csv
# 35   0.081138  0.369951  0.723834  ...       0.0  filtered_ID51.csv
# 36   0.106085  0.491785  0.768079  ...       0.0  filtered_ID51.csv
# 37   0.291241  0.609439  0.866423  ...       0.0  filtered_ID51.csv
# 38   0.330041  0.645780  0.902940  ...       0.0  filtered_ID52.csv
# 39   0.512963  0.649975  0.886926  ...       0.0  filtered_ID52.csv
# 40   0.668526  0.828047  0.777524  ...       0.0  filtered_ID52.csv
# 41   0.504247  0.714669  0.933604  ...       0.0  filtered_ID52.csv
# 42   0.586662  0.795221  0.916160  ...       0.0  filtered_ID52.csv
# 43   0.340816  0.595353  0.630044  ...       0.0  filtered_ID52.csv
# 44   0.274351  0.675833  0.904724  ...       0.0  filtered_ID52.csv
# 45   0.139267  0.789961  0.844404  ...       0.0  filtered_ID53.csv
# 46   0.200760  0.680644  0.767138  ...       0.0  filtered_ID53.csv
# 47   0.294367  0.609355  0.819600  ...       0.0  filtered_ID53.csv
# 48   0.287166  0.602019  0.885416  ...       0.0  filtered_ID53.csv
# 49   0.196374  0.741921  0.922035  ...       0.0  filtered_ID53.csv
# 50   0.208925  0.633315  0.897949  ...       0.0  filtered_ID53.csv
# 51   0.079154  0.628397  0.920616  ...       0.0  filtered_ID53.csv
# 52   0.091405  0.519832  0.905438  ...       0.0  filtered_ID53.csv
# 53   0.483206  0.552001  0.931733  ...       0.0  filtered_ID55.csv
# 54   0.272688  0.455961  0.816510  ...       0.0  filtered_ID55.csv
# 55   0.322848  0.461286  0.927159  ...       0.0  filtered_ID55.csv
# 56   0.496310  0.658230  0.952715  ...       0.0  filtered_ID55.csv
# 57   0.503871  0.472317  0.961655  ...       0.0  filtered_ID55.csv
# 58   0.606078  0.487762  0.691286  ...       0.0  filtered_ID55.csv
# 59   0.297278  0.505455  0.767283  ...       0.0  filtered_ID55.csv
# 60   0.595092  0.701988  0.940687  ...       0.0  filtered_ID55.csv
# 61   0.352237  0.623895  0.974985  ...       0.0  filtered_ID55.csv
# 62   0.729884  0.741695  0.704154  ...       0.0  filtered_ID55.csv
# 63   0.751638  0.859662  0.939136  ...       0.0  filtered_ID60.csv
# 64   0.359865  0.511740  0.816432  ...       0.0  filtered_ID60.csv
# 65   0.408029  0.778081  0.835915  ...       0.0  filtered_ID60.csv
# 66   0.374355  0.702089  0.872044  ...       0.0  filtered_ID60.csv
# 67   0.281045  0.637850  0.855360  ...       0.0  filtered_ID60.csv
# 68   0.433714  0.699427  0.836708  ...       0.0  filtered_ID60.csv
# 69   0.292861  0.519757  0.812403  ...       0.0  filtered_ID60.csv
# 70   0.481156  0.784405  0.875534  ...       0.0  filtered_ID60.csv
# 71   0.383714  0.606902  0.798956  ...       0.0  filtered_ID60.csv
# 72   0.781385  0.743569  0.713255  ...       0.0  filtered_ID60.csv
# 73   0.321756  0.572257  0.873491  ...       1.0  filtered_ID71.csv
# 74   0.301402  0.354922  0.811298  ...       1.0  filtered_ID71.csv
# 75   0.358995  0.547970  0.790267  ...       1.0  filtered_ID71.csv
# 76   0.373129  0.534014  0.742782  ...       1.0  filtered_ID71.csv
# 77   0.081993  0.271581  0.841822  ...       1.0  filtered_ID71.csv
# 78   0.461101  0.442448  0.566220  ...       1.0  filtered_ID71.csv
# 79   0.197470  0.329408  0.806737  ...       1.0  filtered_ID71.csv
# 80   0.242358  0.507861  0.714445  ...       1.0  filtered_ID71.csv
# 81   0.405303  0.358031  0.705953  ...       1.0  filtered_ID71.csv
# 82   0.158245  0.497919  0.793132  ...       1.0  filtered_ID71.csv
# 83   0.208703  0.390361  0.859971  ...       1.0  filtered_ID72.csv
# 88             0.086774              1.165609         3.771098
# 89             0.057244              1.238503         1.622895
# 90             0.009458              0.700146         2.982562
# 91             0.032589              0.901236         0.220453
# 92             0.032385              1.106182         2.772094
# 93             0.031076              1.269012         2.221330
# 94             0.038894              0.348141         0.404615
# 95             0.074719              0.695834        -0.848524
# 96             0.003328              0.255487        -1.391628
# 97             0.023919              0.585886         1.015888
# 98             0.013540              0.621477         0.866756
# 99             0.009815              0.618251        -2.148076
# 100            0.030837              1.141052         6.101136
# 101            0.020839              1.080857         1.015086
# 102            0.055863              1.539611         1.348406
# 103            0.020480              0.586165         5.798941
# 104            0.032679              0.859976         2.745940
# 105            0.027116              0.918052         6.441542
# 106            0.072104              0.430107        -1.184394
# 107            0.029858              1.135656         5.766152
# 108            0.070441              1.205602         0.055298
# 109            0.011426              0.623602         1.204801
#
# [110 rows x 27 columns]
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	25
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	25
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	25
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	25
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	25
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	25
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	25
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	17
# Tentative: 	8
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	0
# Iteration: 	13 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	0
# Iteration: 	14 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	0
# Iteration: 	15 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	0
# Iteration: 	16 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	0
# Iteration: 	17 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	0
# Iteration: 	18 / 100
# Confirmed: 	19
# Tentative: 	6
# Rejected: 	0
# Iteration: 	19 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	0
# Iteration: 	20 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	0
# Iteration: 	21 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	0
# Iteration: 	22 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	0
# Iteration: 	23 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	0
# Iteration: 	24 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	0
# Iteration: 	25 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	0
# Iteration: 	26 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	0
# Iteration: 	27 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	0
# Iteration: 	28 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	0
# Iteration: 	29 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	30 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	31 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	32 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	33 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	34 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	35 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	36 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	37 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	38 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	39 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	40 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	41 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	42 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	43 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	44 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	45 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	46 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	47 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	48 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	49 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	50 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	51 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	52 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	53 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	54 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	55 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	56 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	57 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	58 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	59 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	60 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	61 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	62 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	63 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	64 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	65 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	66 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	67 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	68 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	69 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	70 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	71 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	72 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	73 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	74 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	75 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	76 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	77 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	78 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	79 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	80 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	81 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	82 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	83 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	84 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	85 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	86 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	87 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	88 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	89 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	90 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	91 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	92 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	93 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	94 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	95 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	96 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	97 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	98 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
# Iteration: 	99 / 100
# Confirmed: 	22
# Tentative: 	2
# Rejected: 	1
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	22
# Tentative: 	1
# Rejected: 	2
# 削除前の特徴量数：25
# 削除された特徴量数：3
# 削除された特徴量一覧
# ['AU05' 'AU14' 'mfcc4_sma3']
# ---fold1---
#
# 最適なハイパーパラメータ：{'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 200}
# CVでのmax精度(Accuracy):0.6271
# --- グリッドサーチの全試行結果 ---
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_max_depth  param_min_samples_split  param_n_estimators                                             params  split0_test_score  split1_test_score  split2_test_score  split3_test_score  split4_test_score  mean_test_score  std_test_score  rank_test_score
# 
# 16       0.195377      0.005081         0.008087        0.002539               5                       10                 100  {'max_depth': 5, 'min_samples_split': 10, 'n_e...           0.622222           0.597826           0.651163           0.571429             0.5250         0.593528        0.043239               35
# 17       0.398657      0.017859         0.012384        0.002293               5                       10                 200  {'max_depth': 5, 'min_samples_split': 10, 'n_e...           0.633333           0.608696           0.639535           0.558442             0.5375         0.595501        0.040699               34
# 18       0.116911      0.004567         0.005399        0.000599              10                        2                  50  {'max_depth': 10, 'min_samples_split': 2, 'n_e...           0.644444           0.684783           0.674419           0.610390             0.4750         0.617807        0.075959               13
# 19       0.223739      0.007857         0.008196        0.001285              10                        2                 100  {'max_depth': 10, 'min_samples_split': 2, 'n_e...           0.633333           0.663043           0.674419           0.558442             0.5000         0.605847        0.066603               30
# 20       0.471997      0.014655         0.014706        0.000466              10                        2                 200  {'max_depth': 10, 'min_samples_split': 2, 'n_e...           0.622222           0.630435           0.709302           0.584416             0.5250         0.614275        0.060359               20
# 21       0.116331      0.005573         0.005829        0.001618              10                        5                  50  {'max_depth': 10, 'min_samples_split': 5, 'n_e...           0.666667           0.565217           0.662791           0.623377             0.5250         0.608610        0.055494               27
# 22       0.219187      0.011616         0.007421        0.001355              10                        5                 100  {'max_depth': 10, 'min_samples_split': 5, 'n_e...           0.622222           0.641304           0.674419           0.610390             0.5375         0.617167        0.045340               17
# 23       0.451974      0.011876         0.012764        0.002035              10                        5                 200  {'max_depth': 10, 'min_samples_split': 5, 'n_e...           0.633333           0.630435           0.697674           0.597403             0.5500         0.621769        0.048404                4
# 24       0.115846      0.008201         0.005515        0.001461              10                       10                  50  {'max_depth': 10, 'min_samples_split': 10, 'n_...           0.633333           0.673913           0.662791           0.571429             0.5125         0.610793        0.060675               23
# 25       0.227425      0.009784         0.008515        0.001578              10                       10                 100  {'max_depth': 10, 'min_samples_split': 10, 'n_...           0.622222           0.641304           0.686047           0.558442             0.5375         0.609103        0.054448               26
# 26       0.463689      0.011187         0.016011        0.000540              10                       10                 200  {'max_depth': 10, 'min_samples_split': 10, 'n_...           0.644444           0.630435           0.732558           0.532468             0.5250         0.612981        0.077222               21
# 27       0.119005      0.005586         0.005643        0.000715              15                        2                  50  {'max_depth': 15, 'min_samples_split': 2, 'n_e...           0.666667           0.652174           0.686047           0.610390             0.4875         0.620555        0.071024                8
# ...
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	75 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	76 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	77 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	78 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	79 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	80 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	81 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	82 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	83 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	84 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	85 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	86 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	87 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	88 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	89 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	90 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	91 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	92 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	93 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	94 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	95 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	96 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	97 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	98 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
# Iteration: 	99 / 100
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	0
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	22
# Tentative: 	1
# Rejected: 	2
# 削除前の特徴量数：25
# 削除された特徴量数：3
# 削除された特徴量一覧
# ['AU15' 'AU25' 'mfcc4_sma3']
# ---fold5---
#
# 最適なハイパーパラメータ：{'max_depth': None, 'min_samples_split': 2, 'n_estimators': 50}
# CVでのmax精度(Accuracy):0.5607
# --- グリッドサーチの全試行結果 ---
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_max_depth  param_min_samples_split  param_n_estimators                                             params  split0_test_score  split1_test_score  split2_test_score  split3_test_score  split4_test_score  mean_test_score  std_test_score  rank_test_score
# 
# 32       0.577974      0.061872         0.014842        0.004337              15                        5                 200  {'max_depth': 15, 'min_samples_split': 5, 'n_e...           0.488372           0.629213           0.688172           0.470588           0.426829         0.540635        0.100203               14
# 33       0.148726      0.010062         0.006118        0.000985              15                       10                  50  {'max_depth': 15, 'min_samples_split': 10, 'n_...           0.453488           0.696629           0.645161           0.505882           0.390244         0.538281        0.115457               18
# 34       0.297437      0.025530         0.009278        0.001501              15                       10                 100  {'max_depth': 15, 'min_samples_split': 10, 'n_...           0.453488           0.696629           0.677419           0.517647           0.426829         0.554403        0.112402                3
# 35       0.495366      0.022117         0.008918        0.004245              15                       10                 200  {'max_depth': 15, 'min_samples_split': 10, 'n_...           0.465116           0.617978           0.655914           0.505882           0.426829         0.534344        0.088245               22
# テストデータでの正解率: 0.55
#
# 各テストファイルごとの分類結果
#
#                                     voice           filename  ID  Delirium  \
# 1   ..\voice\voice_csv_20ms\ID37_20ms.csv  filtered_ID37.csv  37         0
# 21  ..\voice\voice_csv_20ms\ID57_20ms.csv  filtered_ID57.csv  57         1
# 23  ..\voice\voice_csv_20ms\ID59_20ms.csv  filtered_ID59.csv  59         0
# 25  ..\voice\voice_csv_20ms\ID61_20ms.csv  filtered_ID61.csv  61         0
# 26  ..\voice\voice_csv_20ms\ID62_20ms.csv  filtered_ID62.csv  62         0
# 27  ..\voice\voice_csv_20ms\ID63_20ms.csv  filtered_ID63.csv  63         1
# 30  ..\voice\voice_csv_20ms\ID66_20ms.csv  filtered_ID66.csv  66         0
# 38  ..\voice\voice_csv_20ms\ID74_20ms.csv  filtered_ID74.csv  74         1
# 46  ..\voice\voice_csv_20ms\ID82_20ms.csv  filtered_ID82.csv  82         1
# 54  ..\voice\voice_csv_20ms\ID90_20ms.csv  filtered_ID90.csv  90         1
# 58  ..\voice\voice_csv_20ms\ID94_20ms.csv  filtered_ID94.csv  94         1
#
#     Predictions
# 1           1.0
# 21          1.0
# 23          1.0
# 25          1.0
# 26          1.0
# 27          1.0
# 30          1.0
# 38          1.0
# 46          1.0
# 54          1.0
# 58          1.0
#
#
# 正解率 (ファイル単位): 0.5455 (6/11 ファイル正解)
#
# 混同行列:
#        予測: 0  予測: 1
# 正解: 0      0      5
# 正解: 1      0      6
#
#
#                   Feature  Importance
# 4                    AU06    0.070534
# 7                    AU12    0.066709
# 12                   AU26    0.060393
# 16             mfcc1_sma3    0.060203
# 0                    AU01    0.060039
# 2                    AU04    0.053867
# 8                    AU14    0.049232
# 17             mfcc2_sma3    0.047362
# 3                    AU05    0.047080
# 14                   AU43    0.042997
# 18             mfcc3_sma3    0.041708
# 10                   AU23    0.041633
# 5                    AU09    0.040700
# 1                    AU02    0.040464
# 15      spectralFlux_sma3    0.039280
# 9                    AU17    0.039223
# 21        HNRdBACF_sma3nz    0.037293
# 13                   AU28    0.034643
# 11                   AU24    0.034587
# 19     jitterLocal_sma3nz    0.033188
# 6                    AU10    0.031037
# 20  shimmerLocaldB_sma3nz    0.027828
