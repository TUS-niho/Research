# %% [markdown]
# Multimodal（表情&音声）　RandomForest

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import os
#from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from scipy.stats import mode
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import shap

pd.options.display.max_rows = None

folder_face_path = Path(r"C:\Users\robotics\proj\Research\output_filtered_questions")
face_files = list(folder_face_path.glob('*.csv'))
face_df = pd.DataFrame({'facepath': face_files})
face_df['facename'] = face_df['facepath'].apply(lambda p: Path(p).name)
#print(face_df)

# ファイルとdeliriumの結合
folder_path = Path(r"C:\Users\robotics\proj\Research\code\voice\voice_csv_20ms")
all_files = list(folder_path.glob('*.csv'))


df = pd.DataFrame({'filepath': all_files})
#print(df)

files_df = df 

#print(files_df)
files_df['filename'] = df['filepath'].apply(lambda p: Path(p).name)
files_df = pd.concat([files_df, face_df], axis=1)
#print(files_df)


files_df['ID'] = files_df['filename'].str.extract(r'ID(\d+)_')
files_df['ID'] = files_df['ID'].astype(int)
#print(files_df)

labels_df = pd.read_csv(r"C:\Users\robotics\proj\Research\code\voice\delirium.csv")
#print(labels_df)

file_with_labels_df = pd.merge(files_df, labels_df, on='ID', how='left')

file_with_labels_df.drop(columns=['ID', 'Sex'], inplace=True)
#print(file_with_labels_df)
#print(file_with_labels_df.columns)

#KFold Cross Validation
model = RandomForestClassifier(random_state=42)
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = []

#CSVファイルのデータ
X_files = file_with_labels_df
#print(X_files)
#せん妄の有無(0 or 1)
y_labels = file_with_labels_df['Delirium']
#print(y_labels[2])

for fold, (train_indices, test_indices) in enumerate(kf.split(X_files, y_labels)):

    train_files = X_files.iloc[train_indices]
    test_files = X_files.iloc[test_indices]
    #print(train_indices)
    #print(train_files)

    print(f"--- Fold {fold+1} ---")
    print(f"訓練ファイル数: {len(train_files)}, テストファイル数: {len(test_files)}")

    #print(test_files)
    #音声ファイルのパスを取得
    train_files_path = [folder_path / fname for fname in train_files['filename']]
    test_files_path = [folder_path / fname for fname in test_files['filename']]
    #表情ファイルのパスを取得
    face_train_path = [folder_face_path / fname for fname in train_files['facepath']]
    face_test_path = [folder_face_path / fname for fname in test_files['facepath']]

    #print(face_train_path)
    train_df = pd.DataFrame()
    test_df = pd.DataFrame()
    for v, f in zip(train_files_path, face_train_path):
        #df_train_file = pd.read_csv(f).iloc[::2]
        df_train_file = pd.read_csv(v)
        df_face_train_file = pd.read_csv(f)

        #print(df_face_train_file)
        #print(f)
        current_filename = os.path.basename(v)
        #print(current_filename)
        rows = train_files[train_files['filename'] == current_filename]
        #print(rows)
        file_delirium = rows['Delirium'].iloc[0]
        #print(file_delirium)
        df_train_file['Delirium'] = file_delirium
        df_train_file['filename'] = current_filename
        #print(df_train_file)

        #df_train_file['Delirium'] = train_files[train_files['filename'] == current_filename]['Delirium'].iloc[2]
        
        #delete space
        df_train_file['label'] = df_train_file['label'].str.strip()
        df_face_train_file['label'] = df_face_train_file['label'].astype(str).str.strip()

        #only answer1-10
        max_df1 = df_train_file[df_train_file["label"].str.match('^answer(10|[1-9])$', na=False)]

        max_df2 = df_face_train_file[df_face_train_file['label'].str.match('^answer(10|[1-9])$', na=False)]
        confidence_to_delete = max_df2['Confidence'] <= 0.90
        rows_to_delete = max_df2[confidence_to_delete].index
        new_max_df2 = max_df2.drop(rows_to_delete)
        columns_to_extract = ["label"] + [col for col in new_max_df2.columns if col.startswith("AU")]
        new_max_df2 = new_max_df2[columns_to_extract]
        
        
        max_df1_file = max_df1.dropna()
        #max_df2_file = new_max_df2.dropna()

        columns_to_convert = ['start', 'end', 'original_start', 'original_end', 'filename']

        # forループを使って、指定した列を順番に数値型に変換
        for col in columns_to_convert:
            max_df1_file[col] = pd.to_numeric(max_df1_file[col], errors='coerce')

        #max_df1_file.info()

        max_df_train_file = max_df1_file.groupby('label').max()
        max_face_train_file = new_max_df2.groupby('label').max()
        #print(max_df_train_file)

        max_df_train_file = max_df_train_file.reset_index(drop=True)
        max_face_train_file = max_face_train_file.reset_index(drop=True)
        #print(max_df_train_file)
        max_multimodal_train_file = pd.concat([max_face_train_file, max_df_train_file], axis=1)

        train_df = pd.concat([train_df, max_multimodal_train_file], ignore_index=True)

        #print(train_df)
    #train_df.to_csv('output.csv', index=False, encoding='utf-8-sig')
    test_file_lengths = []
    for v, f in zip(test_files_path, face_test_path):
        #df_test_file = pd.read_csv(f).iloc[::2]
        df_test_file = pd.read_csv(v)
        df_face_test_file = pd.read_csv(f)

        #print(f)
        current_filename = os.path.basename(v)

        #print(current_filename)
        rows = test_files[test_files['filename'] == current_filename]
        #print(rows)
        file_delirium = rows['Delirium'].iloc[0]
        #print(file_delirium)
        df_test_file['Delirium'] = file_delirium
        df_test_file['filename'] = current_filename

        #delete space
        df_test_file['label'] = df_test_file['label'].str.strip()
        df_face_test_file['label'] = df_face_test_file['label'].astype(str).str.strip()
        #only answer1-10
        max_df3 = df_test_file[df_test_file["label"].str.match('^answer(10|[1-9])$', na=False)]
        #face
        max_df4 = df_face_test_file[df_face_test_file['label'].str.match('^answer(10|[1-9])$', na=False)]
        confidence_to_delete = max_df4['Confidence'] <= 0.90
        rows_to_delete = max_df4[confidence_to_delete].index
        new_max_df4 = max_df4.drop(rows_to_delete)
        columns_to_extract = ["label"] + [col for col in new_max_df4.columns if col.startswith("AU")]
        new_max_df4 = new_max_df4[columns_to_extract]

        max_df3_file = max_df3.dropna()
        #max_df4_file = new_max_df4.dropna()

        columns_to_convert = ['start', 'end', 'original_start', 'original_end', 'filename']

        # forループを使って、指定した列を順番に数値型に変換
        for col in columns_to_convert:
            max_df3_file[col] = pd.to_numeric(max_df3_file[col], errors='coerce')

        max_df_test_file = max_df3_file.groupby('label').max()
        max_face_test_file = new_max_df4.groupby('label').max()

        max_df_test_file = max_df_test_file.reset_index(drop=True)
        max_face_test_file = max_face_test_file.reset_index(drop=True)

        max_multimodal_test_file = pd.concat([max_face_test_file, max_df_test_file], axis=1)

        test_file_lengths.append(len(max_df_test_file))

        test_df = pd.concat([test_df, max_multimodal_test_file], ignore_index=True)
    #test_df.to_csv('output.csv', index=False, encoding='utf-8-sig')
    #print(train_df)
    #print(test_df)


    #train_df = pd.concat([pd.read_csv(f).iloc[::2] for f in train_files_path], ignore_index=True)
    #test_df = pd.concat([pd.read_csv(f).iloc[::2] for f in test_files_path], ignore_index=True)

    #train_df = pd.concat([pd.read_csv(f) for f in train_files_path], ignore_index=True)
    #test_df = pd.concat([pd.read_csv(f) for f in test_files_path], ignore_index=True)
    #print(train_df)
    #print(test_df)

    print(f"訓練データ行数: {len(train_df)}")
    #train_df = train_df.iloc[::2]
    #train_df = train_df.reset_index(drop=True)
    #print(f"間引き後の訓練データ行数: {len(train_df)}")

    print(f"テストデータ行数: {len(test_df)}")
    #test_df = test_df.iloc[::2]
    #test_df = test_df.reset_index(drop=True)
    #print(f"間引き後の訓練データ行数: {len(test_df)}")


    columns_drop = ['start', 'end', 'label', 'alphaRatio_sma3', 'hammarbergIndex_sma3', 'slope0-500_sma3', 'slope500-1500_sma3', 'mfcc1_sma3', 'mfcc2_sma3', 'mfcc3_sma3', 'mfcc4_sma3','Loudness_sma3', 'logRelF0-H1-H2_sma3nz', 'logRelF0-H1-A3_sma3nz', 'original_start', 'original_end', 'Delirium', 'filename', 'AU07', 'AU11', 'AU20']
    #'Loudness_sma3'

    #print(train_indices)
    #print(test_indices)

    #y_train = y_labels.iloc[train_indices].repeat([len(pd.read_csv(f)) for f in train_files_path])
    #y_test = y_labels.iloc[test_indices].repeat([len(pd.read_csv(f)) for f in test_files_path])
    #print(y_train)

    #print(f"元の訓練データ行数: {len(y_train)}")
    #y_train = y_train.iloc[::2]
    #y_train = y_train.reset_index(drop=True)
    #print(f"間引き後の訓練データ行数: {len(y_train)}")

    #print(f"元のテストデータ行数: {len(y_test)}")
    #y_test = y_test.iloc[::2]
    #y_test = y_test.reset_index(drop=True)
    #print(f"間引き後のテストデータ行数: {len(y_test)}")

    y_train = train_df['Delirium']
    #print(y_train)
    y_test = test_df['Delirium']
    #print(y_test)
    X_train = train_df.drop(columns=columns_drop, errors='ignore')
    X_test = test_df.drop(columns=columns_drop, errors='ignore')
    
    print(X_train)

    print(f"訓練データの正解ラベル数: {len(y_train)}")
    print(f"テストデータの正解ラベル数: {len(y_test)}")

    #print(X_train)

    #NaNの数をカウント
    print(y_train.isnull().sum())

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_true = y_test
    #print(y_pred)

    file_predictions = []

    # 各テストファイルの行数を事前に計算しておく

    #test_file_lengths = [len(pd.read_csv(f).iloc[::2]) for f in test_files_path]
    #print(test_file_lengths)

    start_idx = 0
    for length in test_file_lengths:
        end_idx = start_idx + length
        #print(start_idx, end_idx)
        predictions_for_this_file = y_pred[start_idx:end_idx]
        #print(predictions_for_this_file)
        majority_vote = mode(predictions_for_this_file)[0]
        #print(majority_vote)
        file_predictions.append([majority_vote, start_idx, end_idx])
        start_idx = end_idx

    first_column_list = [item[0] for item in file_predictions]

    #print(file_predictions)

    y_test_files = test_files['Delirium'].values

    #print(y_test_files)

    test_files_copy = test_files
    #test_files_copy['Predict'] = file_predictions
    test_files_copy = test_files_copy.assign(Prediction=first_column_list)

    print(test_files_copy)

    correct_files = np.sum(np.array(first_column_list) == y_test_files)
    total_files = len(test_files)
    accuracy = correct_files/ total_files

    scores.append(accuracy)
    print("\n")
    print(f"このFoldの正解率 (ファイル単位): {accuracy:.4f} ({correct_files}/{total_files} ファイル正解)\n")

    # 4-2. 混同行列の計算
    # y_test_files (正解ラベル) と file_predictions (予測ラベル) を渡す
    cm = confusion_matrix(y_test_files, first_column_list)

    # 4-3. 見やすいようにDataFrameに変換して表示
    # ラベルが0と1の場合
    cm_df = pd.DataFrame(cm, 
                     index=['正解: 0', '正解: 1'], 
                     columns=['予測: 0', '予測: 1'])

    print("混同行列:")
    print(cm_df)
    print("\n") # 見やすいように改行

    #特徴量の重要度を取得
    feature_names = X_train.columns.tolist()
    
    importances = model.feature_importances_

    #特徴量の名前と重要度をまとめたDataFrameを作成
    importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': importances
    })

    #重要度が高い順にソート
    sorted_importance_df = importance_df.sort_values(by='Importance', ascending=False)

    print(sorted_importance_df)

    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X_train) 

    #shap_values 全体の形状を確認 (おそらく (479, 14, 2))
    print(f"SHAP Values (全体) の形状: {shap_values.shape}")

    #せん妄ありのSHAP値だけをスライス ---
    shap_values_class1 = shap_values[:, :, 1]

    #スライスした後の形状を確認 (これで (479, 14) になるはず)
    print(f"SHAP Values (Class 1) の形状: {shap_values_class1.shape}")
    #print(f"X_train の形状: {X_train.shape}")

    #スライスした shap_values_class1 を渡す
    shap.summary_plot(shap_values_class1, X_train)

    #予測が0で正解が1の場合
    shap.initjs()

    misclassified_indices = []

    for pred, true_label, full_item in zip(first_column_list, y_test_files, file_predictions):

        if (pred == 0) & (true_label == 1):
            start_idx = full_item[1]
            end_idx = full_item[2]

            misclassified_indices.append((start_idx, end_idx))

    print(f"間違えたファイルの (start, end) リスト: {misclassified_indices}")

    #間違えたセグメントを格納するための空のリスト
    X_test_errors_list = []

    for start, end in misclassified_indices:
        #X_test から start から end までのセグメントをスライス
        #(iloc は X_test がDataFrameの場合。Numpy配列なら X_test[start:end] )
        segment = X_test.iloc[start:end] 
        X_test_errors_list.append(segment)

    #抜き出したセグメントをすべて結合
    if X_test_errors_list:
        X_test_errors = pd.concat(X_test_errors_list) #DataFrameの場合
        
        #これで初めて X_test_errors に対して SHAP が実行できる
        shap_values_errors = explainer.shap_values(X_test_errors)
        
        print(f"SHAP Values (error) の形状: {shap_values_errors.shape}")
        shap.summary_plot(shap_values_errors[:, :, 1], X_test_errors)
    else:
        print("該当するエラーはありませんでした。")

    #特徴量ごとの散布図を比較
    #feature_name = 'Loudness_sma3'

    #fig, (sp1, sp2) = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
    #fig.suptitle(f'{feature_name}', fontsize=16)

    #sp1.scatter(range(len(X_train)), X_train[feature_name], alpha=0.6)
    #sp1.set_title('train data')
    #sp1.set_xlabel('index')
    #sp1.set_ylabel(feature_name)
    #sp1.grid(True)

    #sp2.scatter(range(len(X_test)), X_test[feature_name], alpha=0.6)
    #sp2.set_title('test data')
    #sp2.set_xlabel('index')
    #sp2.set_ylabel(feature_name)
    #sp2.grid(True)

    #グラフを表示
    #plt.tight_layout(rect=[0, 0.03, 1, 0.95])a
    #plt.show()

    

total_accuracy = sum(scores) / len(scores)
print(f"5つのFoldのファイル単位での平均正解率：{total_accuracy:.4f}\n")
print(f"5つのFoldのファイル単位での性能のばらつき(標準偏差)：{np.std(scores):.4f}")
# Out:
# --- Fold 1 ---
# 訓練ファイル数: 47, テストファイル数: 12
# 訓練データ行数: 426
# テストデータ行数: 112
#          AU01      AU02      AU04      AU05      AU06      AU09      AU10  \
# 0    0.895931  0.897232  0.641082  0.539894  0.518501  0.579164  0.802194
# 1    0.901063  0.875309  0.875354  0.363666  0.943962  0.854595  0.998760
# 2    0.887286  0.884554  0.727427  0.562549  0.424385  0.660849  0.947380
# 3    0.889474  0.896892  0.849278  0.472705  0.482916  0.573833  0.824520
# 4    0.917090  0.896238  0.830765  0.573845  0.788184  0.728424  0.982635
# 5    0.883416  0.885176  0.761784  0.493048  0.490108  0.547728  0.646625
# 6    0.938441  0.922835  0.708618  0.755264  0.657917  0.610747  0.958211
# 7    0.924173  0.928169  0.630959  0.553323  0.915084  0.679032  0.998175
# 8    0.936104  0.902742  0.362310  0.552247  0.552693  0.607492  0.835767
# 9    0.869587  0.880750  0.894331  0.537201  0.673733  0.614166  0.924783
# 10   0.912299  0.756215  0.484955  0.468714  0.119333  0.159885  0.069642
# 11   0.929945  0.853684  0.658170  0.390620  0.558156  0.512596  0.991839
# 12   0.927042  0.832492  0.694495  0.352433  0.331544  0.526487  0.847773
# 13   0.938727  0.886992  0.831452  0.711100  0.463952  0.512202  0.954360
# 14   0.931829  0.889255  0.837220  0.489988  0.269465  0.672910  0.942098
# 15   0.951068  0.931664  0.740404  0.757581  0.222187  0.218392  0.854880
# 16   0.924358  0.872210  0.751265  0.717600  0.118840  0.195674  0.712288
# 17   0.946176  0.885463  0.712511  0.767913  0.280083  0.417183  0.996457
# 18   0.909091  0.813698  0.697257  0.318897  0.360729  0.514261  0.928062
# 19   0.932829  0.775934  0.497966  0.556394  0.176047  0.218961  0.584923
# 20   0.777489  0.535435  0.578409  0.632573  0.451643  0.358985  0.736051
# 21   0.794272  0.620501  0.734319  0.544411  0.763358  0.514601  0.996045
# 22   0.777211  0.489627  0.368145  0.638834  0.353483  0.277408  0.766769
# 23   0.725350  0.470209  0.544369  0.582270  0.456748  0.374637  0.726079
# 24   0.766321  0.494406  0.528994  0.534981  0.448534  0.472231  0.850695
# 25   0.808239  0.555101  0.683179  0.604327  0.367604  0.366481  0.388434
# 26   0.786113  0.550655  0.736593  0.487316  0.787487  0.554693  0.999612
# 27   0.803873  0.483375  0.667236  0.433150  0.632690  0.407312  0.988942
# 28   0.635418  0.405426  0.529745  0.564261  0.583106  0.325051  0.934525
# 29   0.616196  0.434796  0.563216  0.479840  0.477176  0.364029  0.978437
# 30   0.640789  0.291020  0.666773  0.264401  0.198877  0.504464  0.736578
# 31   0.927451  0.842370  0.813500  0.615277  0.592748  0.610158  0.974861
# 32   0.850836  0.489330  0.872401  0.477060  0.214440  0.452645  0.424274
# 33   0.852315  0.621949  0.711844  0.476930  0.107666  0.178777  0.138056
# 34   0.896139  0.800748  0.859918  0.565721  0.175029  0.410173  0.855844
# 35   0.884432  0.807217  0.492651  0.525988  0.099427  0.205962  0.498783
# 36   0.865916  0.688811  0.919670  0.502958  0.114999  0.441573  0.120452
# 37   0.899736  0.763927  0.874923  0.501652  0.293689  0.440763  0.717070
# 38   0.874168  0.727800  0.590521  0.441169  0.359508  0.283727  0.285297
# 39   0.786716  0.253426  0.920101  0.490709  0.107120  0.353778  0.148418
# 40   0.781123  0.619045  0.298862  0.399394  0.107354  0.168820  0.056335
# 41   0.891524  0.671284  0.366442  0.503342  0.144475  0.317971  0.007249
# 42   0.911891  0.826881  0.586686  0.702823  0.276154  0.390364  0.735648
# 43   0.907032  0.728503  0.471862  0.723367  0.134362  0.218705  0.809679
# 44   0.905769  0.818789  0.916947  0.698578  0.505059  0.607498  0.928522
# 45   0.733026  0.795838  0.697363  0.673118  0.393439  0.478098  0.928492
# 46   0.819873  0.705822  0.838387  0.685531  0.511653  0.567439  0.645719
# 47   0.813615  0.626124  0.369117  0.667326  0.140361  0.415149  0.343711
# 48   0.758361  0.599337  0.238298  0.657023  0.103565  0.140007  0.891335
# 49   0.781008  0.457791  0.688051  0.659350  0.214286  0.192239  0.428052
# 50   0.856889  0.759655  0.776239  0.531960  0.465989  0.507977  0.810701
# 51   0.926325  0.811228  0.686183  0.367141  0.714807  0.513519  0.990094
# 52   0.915930  0.775203  0.688735  0.373764  0.439134  0.502378  0.959574
# 53   0.915494  0.798248  0.617967  0.330616  0.563135  0.519032  0.935535
# 54   0.890454  0.835360  0.433061  0.383074  0.284685  0.439158  0.839738
# 55   0.899758  0.809527  0.545424  0.373455  0.547573  0.434035  0.968463
# 56   0.920491  0.802585  0.590568  0.387282  0.609763  0.589110  0.967046
# 57   0.904562  0.793923  0.674702  0.403155  0.626348  0.521191  0.992249
# 58   0.915078  0.791993  0.520226  0.358645  0.596220  0.535966  0.956410
# 59   0.900872  0.824030  0.564372  0.352376  0.335231  0.435693  0.854760
# 60   0.802877  0.578445  0.880818  0.564523  0.258916  0.572965  0.949128
# 61   0.577754  0.436342  0.728956  0.406655  0.137717  0.324251  0.002294
# 62   0.723047  0.520864  0.748390  0.406034  0.122219  0.353241  0.011337
# 63   0.830864  0.624241  0.951307  0.415829  0.463472  0.611294  0.938720
# 64   0.835165  0.607449  0.911602  0.759203  0.182325  0.612509  0.573722
# 65   0.875623  0.784523  0.850739  0.747622  0.562481  0.687645  0.945400
# 66   0.884061  0.715420  0.850746  0.753195  0.179997  0.410455  0.793514
# 67   0.724520  0.790253  0.821001  0.446884  0.487582  0.471968  0.709171
# 68   0.569787  0.424083  0.876023  0.432052  0.237175  0.572515  0.724121
# 69   0.799881  0.516033  0.698063  0.473679  0.442770  0.470989  0.146873
# 70   0.820439  0.873241  0.928084  0.593881  0.730664  0.686622  0.619842
# 71   0.788900  0.848156  0.953857  0.706725  0.380794  0.623444  0.970931
# 72   0.765518  0.818050  0.939577  0.736249  0.282896  0.567004  0.360356
# 73   0.828756  0.814527  0.797245  0.595959  0.352312  0.583355  0.673087
# 74   0.859387  0.857112  0.965272  0.703656  0.873952  0.674768  0.848870
# 75   0.819210  0.860719  0.922282  0.746268  0.539754  0.682846  0.835594
# 76   0.794750  0.815455  0.914426  0.576183  0.768876  0.682249  0.846240
# 77   0.764101  0.755027  0.675652  0.523076  0.386788  0.583342  0.058263
# 78   0.815368  0.826589  0.928041  0.557857  0.742695  0.675055  0.936610
# 79   0.708485  0.764625  0.746864  0.514225  0.453553  0.396672  0.994769
# 80   0.833923  0.812980  0.953850  0.715256  0.875948  0.754277  0.998743
# 81   0.820577  0.778281  0.927291  0.713340  0.559508  0.589866  0.939015
# 82   0.826175  0.780856  0.890240  0.715196  0.551664  0.616555  0.980209
# 83   0.815838  0.790328  0.959253  0.707006  0.900099  0.834360  0.998788
# 84   0.823165  0.831921  0.933705  0.695937  0.890360  0.753328  0.957930
# 85   0.819447  0.767212  0.965790  0.696975  0.845738  0.775509  0.998164
# 86   0.839734  0.840083  0.954004  0.729008  0.537330  0.654494  0.988050
# 87   0.839120  0.846558  0.948123  0.721584  0.897481  0.744012  0.997203
# 88   0.801035  0.789262  0.955584  0.737022  0.796841  0.681743  0.992898
# 89   0.866061  0.798210  0.878591  0.611827  0.324578  0.762034  0.599545
# 90   0.813738  0.830083  0.755722  0.755650  0.895741  0.700138  0.979396
# 91   0.802780  0.762546  0.692175  0.709667  0.404153  0.495773  0.658375
# 92   0.840839  0.746385  0.791445  0.698163  0.871478  0.660247  0.799435
# 93   0.869492  0.823726  0.797607  0.759680  0.819950  0.611785  0.960021
# 94   0.801442  0.765153  0.613455  0.732706  0.835468  0.548708  0.911291
# 95   0.828686  0.813177  0.863215  0.743027  0.864904  0.674859  0.987986
# 96   0.869105  0.834697  0.885163  0.728577  0.860928  0.755684  0.994107
# 97   0.874402  0.838015  0.812351  0.746616  0.891961  0.738879  0.992512
# 98   0.764209  0.728768  0.771786  0.764017  0.497972  0.550575  0.894129
# 99   0.833796  0.829079  0.964284  0.710886  0.874135  0.795778  0.977201
# 100  0.769891  0.769510  0.882538  0.565514  0.659767  0.567294  0.888010
# 101  0.801383  0.760460  0.858093  0.527148  0.516235  0.648385  0.934746
# 102  0.790636  0.794352  0.872055  0.761642  0.563068  0.679931  0.989042
# 103  0.804826  0.791229  0.930619  0.668807  0.889092  0.765313  0.992159
# 104  0.775801  0.838695  0.941361  0.484169  0.707856  0.665372  0.988587
# 105  0.830464  0.809130  0.922758  0.629648  0.624263  0.632526  0.884671
# 106  0.783443  0.756051  0.790926  0.554901  0.535275  0.481232  0.935351
# 107  0.649475  0.622771  0.604046  0.473000  0.432792  0.542205  0.751451
# 108  0.809564  0.830031  0.843675  0.723933  0.826057  0.709190  0.965503
# 109  0.819561  0.831781  0.811934  0.663828  0.735823  0.495495  0.935190
# 110  0.797341  0.682261  0.749700  0.500962  0.360755  0.524436  0.865560
# 111  0.827637  0.828937  0.954258  0.725276  0.924282  0.760437  0.998673
# 112  0.743990  0.768660  0.816988  0.706912  0.568712  0.690108  0.947073
# 113  0.805969  0.800209  0.920735  0.727769  0.890601  0.748511  0.922981
# 114  0.769579  0.788305  0.861117  0.684963  0.779776  0.584192  0.736275
# 115  0.786831  0.761538  0.892268  0.661981  0.884978  0.646098  0.925689
# 116  0.813928  0.836729  0.866851  0.707324  0.890220  0.713880  0.985223
# 117  0.784562  0.741765  0.931696  0.575884  0.918676  0.794430  0.984477
# 118  0.717373  0.633991  0.880089  0.491456  0.511750  0.664530  0.894780
# 119  0.466932  0.256896  0.867481  0.311015  0.341493  0.364976  0.525504
# 120  0.792640  0.709127  0.841693  0.569686  0.926939  0.678242  0.974674
# 121  0.771834  0.683493  0.766724  0.549174  0.834619  0.556162  0.848701
# 122  0.762260  0.616224  0.702860  0.535520  0.906625  0.560452  0.584515
# 123  0.602656  0.486870  0.883008  0.348588  0.843375  0.616516  0.760442
# 124  0.769693  0.722779  0.934907  0.549698  0.887256  0.769850  0.932079
# 125  0.857869  0.721130  0.783817  0.487155  0.668003  0.656110  0.965005
# 126  0.804515  0.755911  0.806674  0.451936  0.771282  0.742337  0.963103
# 127  0.810804  0.645137  0.731240  0.375470  0.460320  0.585482  0.689794
# 128  0.917388  0.810958  0.858498  0.461817  0.359549  0.681346  0.978069
# 129  0.886966  0.784261  0.941992  0.404138  0.516981  0.769385  0.986858
# 130  0.860364  0.714483  0.829940  0.343158  0.179677  0.582988  0.898515
# 131  0.833754  0.706501  0.774398  0.363064  0.170441  0.642595  0.893876
# 132  0.884212  0.847688  0.887114  0.468946  0.586013  0.806203  0.937982
# 133  0.816835  0.607768  0.855846  0.283867  0.182619  0.566377  0.847294
# 134  0.649722  0.425391  0.917549  0.368957  0.218407  0.701558  0.645574
# 135  0.730323  0.736710  0.966265  0.486903  0.686268  0.743181  0.924106
# 136  0.774992  0.754028  0.870043  0.460614  0.089737  0.362092  0.242078
# 137  0.802293  0.788192  0.936663  0.508340  0.765048  0.707225  0.588580
# 138  0.856614  0.825066  0.960577  0.529042  0.352876  0.646676  0.870412
# 139  0.759924  0.754371  0.856139  0.446008  0.262068  0.241728  0.224196
# 140  0.732948  0.811882  0.947541  0.468544  0.298660  0.530597  0.575113
# 141  0.766135  0.762750  0.956197  0.430488  0.154808  0.585276  0.864719
# 142  0.726153  0.707367  0.815176  0.409289  0.122052  0.428360  0.438974
# 143  0.731644  0.675315  0.950077  0.398695  0.109541  0.383008  0.721877
# 144  0.789238  0.493886  0.695083  0.373200  0.398574  0.500629  0.704505
# 145  0.800550  0.841618  0.987826  0.499620  0.899706  0.841618  0.998632
# 146  0.819845  0.786620  0.983553  0.634547  0.551043  0.833002  0.985503
# 147  0.826426  0.788291  0.890187  0.497472  0.680568  0.762525  0.995514
# 148  0.754014  0.839716  0.957115  0.457897  0.729924  0.761765  0.973096
# 149  0.836687  0.776574  0.959369  0.490089  0.927000  0.858997  0.999154
# 150  0.775856  0.764005  0.982594  0.489915  0.949965  0.862807  0.999020
# 151  0.808968  0.694775  0.892414  0.488972  0.831065  0.862585  0.983334
# 152  0.748786  0.733223  0.964562  0.444601  0.371321  0.815916  0.979408
# 153  0.918770  0.831499  0.670627  0.638000  0.787781  0.562868  0.912215
# 154  0.918958  0.820583  0.970144  0.533216  0.833837  0.764058  0.949050
# 155  0.942518  0.871899  0.879550  0.530432  0.908154  0.779481  0.924541
# 156  0.932644  0.853509  0.805900  0.529469  0.503828  0.459890  0.389745
# 157  0.907390  0.799032  0.884399  0.529108  0.788850  0.778810  0.848808
# 158  0.866269  0.823023  0.961265  0.717267  0.557741  0.732671  0.808701
# 159  0.895819  0.919959  0.967542  0.725238  0.879109  0.760046  0.978650
# 160  0.908683  0.899625  0.948652  0.712887  0.490817  0.785518  0.735431
# 161  0.926801  0.889620  0.928803  0.726003  0.884871  0.729108  0.984994
# 162  0.830587  0.701434  0.814946  0.458462  0.848867  0.679142  0.944021
# 163  0.873117  0.745888  0.800735  0.545678  0.234598  0.309298  0.106872
# 164  0.918171  0.801411  0.890230  0.738769  0.755195  0.624125  0.963004
# 165  0.901040  0.791185  0.864304  0.735025  0.457178  0.383840  0.826443
# 166  0.896622  0.831023  0.879971  0.742122  0.923425  0.791115  0.987470
# 167  0.936688  0.863293  0.965663  0.715092  0.936158  0.854916  0.996401
# 168  0.899486  0.860091  0.959471  0.720424  0.502781  0.782878  0.919575
# 169  0.909148  0.870115  0.937648  0.737119  0.573740  0.788595  0.679774
# 170  0.922158  0.861518  0.934082  0.726776  0.914358  0.848541  0.988480
# 171  0.868546  0.743319  0.854210  0.439555  0.756852  0.763075  0.987347
# 172  0.660004  0.663858  0.742615  0.427682  0.399881  0.600148  0.930258
# 173  0.817923  0.854105  0.954082  0.674614  0.901143  0.831060  0.979912
# 174  0.762851  0.739633  0.666093  0.731800  0.893274  0.599700  0.610525
# 175  0.777120  0.686098  0.913362  0.691808  0.890529  0.664468  0.988744
# 176  0.802569  0.834975  0.914051  0.724794  0.899705  0.745796  0.997312
# 177  0.830894  0.759874  0.938366  0.753496  0.897969  0.707657  0.959157
# 178  0.719360  0.743528  0.920503  0.473348  0.200824  0.726345  0.590219
# 179  0.757165  0.754195  0.939472  0.444157  0.339613  0.498368  0.431312
# 180  0.796645  0.813052  0.939237  0.583209  0.826158  0.630934  0.892209
# 181  0.902478  0.762763  0.349695  0.512692  0.133203  0.184944  0.714962
# 182  0.883253  0.808301  0.546998  0.614461  0.398442  0.518955  0.823243
# 183  0.888544  0.775671  0.488846  0.468217  0.211698  0.281485  0.145385
# 184  0.847472  0.710018  0.646924  0.448757  0.165810  0.299608  0.075669
# 185  0.886289  0.811545  0.591496  0.557214  0.193308  0.384456  0.317259
# 186  0.879227  0.810864  0.407750  0.555311  0.226444  0.345588  0.173736
# 187  0.890419  0.810035  0.586315  0.506460  0.242474  0.360053  0.779972
# 188  0.866776  0.813029  0.649720  0.487708  0.216320  0.235353  0.402067
# 189  0.904163  0.853811  0.389739  0.553984  0.296929  0.309686  0.512043
# 190  0.766580  0.756785  0.919195  0.723504  0.530484  0.643364  0.987297
# 191  0.784917  0.689983  0.875593  0.701395  0.516996  0.818089  0.949412
# 192  0.760761  0.705724  0.945749  0.493954  0.786510  0.809629  0.891999
# 193  0.895416  0.851277  0.969789  0.705920  0.565146  0.744014  0.972576
# 194  0.873048  0.749171  0.946454  0.593763  0.568340  0.834551  0.913260
# 195  0.819609  0.749869  0.900978  0.682812  0.628770  0.710510  0.944101
# 196  0.780028  0.707967  0.950108  0.438367  0.677623  0.782408  0.981363
# 197  0.721214  0.601616  0.952457  0.404755  0.367683  0.850884  0.974548
# 198  0.847719  0.735619  0.967706  0.510320  0.804812  0.852781  0.982997
# 199  0.789088  0.779348  0.690290  0.518092  0.895724  0.608552  0.742430
# 200  0.888088  0.821991  0.894674  0.725504  0.896761  0.685909  0.995551
# 201  0.850434  0.848875  0.926033  0.755286  0.872957  0.748728  0.917454
# 202  0.896093  0.859585  0.919040  0.749584  0.898188  0.740383  0.966751
# 203  0.796310  0.798623  0.758835  0.531033  0.843729  0.626118  0.939411
# 204  0.899577  0.829804  0.928722  0.748494  0.875552  0.814914  0.996444
# 205  0.829770  0.831297  0.748841  0.763184  0.882057  0.638264  0.911468
# 206  0.845173  0.871094  0.808463  0.761594  0.896238  0.796288  0.969583
# 207  0.928989  0.868006  0.933856  0.747292  0.913908  0.851548  0.993756
# 208  0.843676  0.861753  0.848773  0.750330  0.792860  0.662582  0.996721
# 209  0.824897  0.895763  0.825291  0.726602  0.692868  0.696726  0.987524
# 210  0.879303  0.876698  0.768954  0.718774  0.807928  0.700282  0.993498
# 211  0.748848  0.796152  0.683209  0.569166  0.389174  0.658495  0.901413
# 212  0.851026  0.864247  0.884032  0.739092  0.572542  0.555816  0.872459
# 213  0.829328  0.803711  0.743681  0.768409  0.373790  0.521232  0.977195
# 214  0.856758  0.873393  0.880070  0.722222  0.532908  0.572229  0.986439
# 215  0.857485  0.816146  0.868515  0.767818  0.661775  0.748174  0.982558
# 216  0.802128  0.839680  0.822764  0.699078  0.457302  0.624170  0.837800
# 217  0.834046  0.867933  0.827043  0.704034  0.660053  0.704486  0.984548
# 218  0.789340  0.773987  0.573131  0.340707  0.697637  0.558377  0.331030
# 219  0.804339  0.768810  0.617001  0.467977  0.826083  0.552948  0.491394
# 220  0.828945  0.744957  0.657177  0.397505  0.779169  0.586464  0.477987
# 221  0.728032  0.746151  0.273595  0.492535  0.537096  0.280472  0.427540
# 222  0.843998  0.770243  0.744646  0.531615  0.849612  0.600104  0.599378
# 223  0.811685  0.752085  0.780276  0.664149  0.906798  0.805148  0.968315
# 224  0.876009  0.853175  0.957410  0.685222  0.940198  0.800484  0.997928
# 225  0.858165  0.826813  0.890422  0.711535  0.936375  0.783933  0.996854
# 226  0.848817  0.812690  0.894199  0.691621  0.895225  0.807362  0.985269
# 227  0.871804  0.835675  0.799106  0.720290  0.894100  0.757872  0.983888
# 228  0.858795  0.838622  0.915188  0.710032  0.948440  0.785274  0.997263
# 229  0.853195  0.870245  0.822671  0.707368  0.897269  0.756415  0.989753
# 230  0.810146  0.832338  0.770105  0.720262  0.913292  0.780826  0.984921
# 231  0.905014  0.836583  0.831222  0.603420  0.727344  0.551853  0.938436
# 232  0.891358  0.785925  0.686578  0.553407  0.223960  0.301448  0.696474
# 233  0.892589  0.796270  0.823684  0.551958  0.349335  0.563076  0.657547
# 234  0.922890  0.802064  0.863234  0.561887  0.247182  0.598255  0.466833
# 235  0.913956  0.821158  0.617569  0.574312  0.464168  0.317652  0.561522
# 236  0.805572  0.411902  0.738547  0.494399  0.113036  0.237645  0.523415
# 237  0.896078  0.771756  0.852640  0.539897  0.334070  0.546147  0.523228
# 238  0.850834  0.585740  0.816798  0.448465  0.238544  0.559149  0.286570
# 239  0.897939  0.824320  0.783940  0.562687  0.240294  0.506933  0.566365
# 240  0.721829  0.759090  0.834634  0.695614  0.943955  0.766648  0.993327
# 241  0.849004  0.798847  0.957230  0.729477  0.907274  0.806779  0.999032
# 242  0.790365  0.812299  0.936641  0.727267  0.945791  0.841792  0.999388
# 243  0.872054  0.869933  0.955659  0.752698  0.893276  0.829436  0.992538
# 244  0.881624  0.904441  0.950090  0.754847  0.951463  0.871873  0.999799
# 245  0.747713  0.763547  0.758566  0.551904  0.947356  0.759532  0.996012
# 246  0.893933  0.802940  0.943446  0.734524  0.931455  0.849603  0.996868
# 247  0.837144  0.826145  0.966742  0.761859  0.865625  0.872782  0.993653
# 248  0.782442  0.841178  0.958989  0.696658  0.898210  0.849456  0.996612
# 249  0.853701  0.784380  0.937896  0.677897  0.944198  0.847397  0.999246
# 250  0.708355  0.490706  0.780773  0.457992  0.189607  0.394306  0.445082
# 251  0.909079  0.664085  0.716125  0.474095  0.781532  0.713087  0.966614
# 252  0.848232  0.683550  0.697498  0.514382  0.371607  0.363726  0.312685
# 253  0.830140  0.671352  0.563651  0.435412  0.419980  0.360052  0.307853
# 254  0.896361  0.782739  0.785274  0.513445  0.704113  0.597827  0.857915
# 255  0.897706  0.808017  0.754413  0.479135  0.759258  0.766615  0.853469
# 256  0.906969  0.735416  0.723701  0.494328  0.599674  0.672290  0.955351
# 257  0.876878  0.680920  0.624146  0.553627  0.569084  0.591517  0.568799
# 258  0.900521  0.770444  0.751551  0.470754  0.822599  0.731341  0.993139
# 259  0.865051  0.576202  0.535037  0.402584  0.236214  0.391806  0.104410
# 260  0.856542  0.816996  0.946915  0.766365  0.914225  0.752666  0.994653
# 261  0.860959  0.710272  0.740788  0.531042  0.802519  0.454970  0.843364
# 262  0.896034  0.794909  0.722983  0.482195  0.161246  0.455749  0.895848
# 263  0.888686  0.755156  0.873473  0.505736  0.825805  0.708885  0.884576
# 264  0.862312  0.680317  0.853048  0.478300  0.160168  0.384490  0.270507
# 265  0.869086  0.876840  0.966791  0.704118  0.941468  0.796038  0.998846
# 266  0.842533  0.720632  0.810921  0.563614  0.876863  0.739607  0.952789
# 267  0.843798  0.697192  0.795477  0.537117  0.786329  0.475957  0.959752
# 268  0.833579  0.789457  0.926398  0.527384  0.923538  0.847819  0.998418
# 269  0.825583  0.689790  0.865355  0.466761  0.625327  0.717015  0.835381
# 270  0.849061  0.797649  0.955471  0.564185  0.930028  0.676468  0.992038
# 271  0.816569  0.730397  0.949693  0.714519  0.835961  0.757915  0.879043
# 272  0.865684  0.741919  0.924975  0.455332  0.931595  0.721309  0.994435
# 273  0.811378  0.761406  0.741869  0.681097  0.942025  0.634278  0.991585
# 274  0.844382  0.717361  0.956205  0.504483  0.937960  0.740740  0.996933
# 275  0.770482  0.735263  0.964044  0.432091  0.925842  0.679837  0.994123
# 276  0.842343  0.664218  0.929882  0.460977  0.905337  0.697406  0.991298
# 277  0.870360  0.822126  0.979963  0.651886  0.941081  0.685902  0.996303
# 278  0.763866  0.691183  0.972054  0.573788  0.691452  0.728287  0.994179
# 279  0.604376  0.467037  0.686165  0.527323  0.752588  0.671080  0.780056
# 280  0.726447  0.742477  0.754263  0.730752  0.801818  0.709279  0.914319
# 281  0.673422  0.577714  0.696017  0.500106  0.553862  0.614692  0.905786
# 282  0.646594  0.665644  0.869870  0.706789  0.894218  0.753525  0.988285
# 283  0.675329  0.724802  0.907369  0.725915  0.728560  0.531868  0.721704
# 284  0.752010  0.680886  0.883728  0.544785  0.825772  0.810835  0.982145
# 285  0.692132  0.611699  0.866576  0.615609  0.848574  0.742813  0.998291
# 286  0.617155  0.522656  0.834323  0.431065  0.272000  0.428150  0.891841
# 287  0.881442  0.853436  0.597628  0.608275  0.610527  0.638317  0.986729
# 288  0.744482  0.812983  0.349117  0.406060  0.509627  0.558693  0.989175
# 289  0.731917  0.837100  0.413120  0.313932  0.534318  0.560296  0.914316
# 290  0.871345  0.834297  0.517009  0.489353  0.505519  0.582499  0.850790
# 291  0.859052  0.843730  0.868614  0.481494  0.612006  0.530570  0.981771
# 292  0.873518  0.775391  0.716065  0.511362  0.444952  0.590453  0.916234
# 293  0.859731  0.798990  0.391883  0.466853  0.557938  0.549409  0.915598
# 294  0.892076  0.850374  0.440731  0.505723  0.251101  0.181285  0.270501
# 295  0.853954  0.618783  0.880600  0.735099  0.084126  0.421656  0.607562
# 296  0.867007  0.691925  0.931472  0.439262  0.218378  0.720790  0.655684
# 297  0.880654  0.586204  0.883701  0.583951  0.085549  0.540253  0.757048
# 298  0.888079  0.539115  0.936243  0.746284  0.160999  0.676354  0.812080
# 299  0.881921  0.534070  0.919794  0.499156  0.156420  0.601187  0.715274
# 300  0.879492  0.446655  0.957532  0.423285  0.075250  0.197814  0.518023
# 301  0.863970  0.747359  0.954073  0.701036  0.417278  0.755123  0.881441
# 302  0.816372  0.383521  0.899193  0.392001  0.195663  0.681097  0.318012
# 303  0.880642  0.465409  0.926789  0.440873  0.172780  0.753626  0.660951
# 304  0.856632  0.343182  0.955671  0.386926  0.221845  0.734630  0.897867
# 305  0.761418  0.749714  0.947926  0.521714  0.884846  0.805471  0.996247
# 306  0.701215  0.639862  0.873567  0.525306  0.883224  0.703709  0.993202
# 307  0.699088  0.576953  0.867730  0.515128  0.888471  0.727766  0.951766
# 308  0.754966  0.623508  0.913699  0.525214  0.861260  0.716580  0.997941
# 309  0.826031  0.748248  0.923332  0.619310  0.872310  0.772349  0.999294
# 310  0.726714  0.616642  0.826351  0.472739  0.863705  0.784924  0.996983
# 311  0.774038  0.706712  0.960734  0.540659  0.890324  0.789991  0.999143
# 312  0.774481  0.708480  0.944872  0.556487  0.878620  0.844902  0.989695
# 313  0.859405  0.858883  0.948635  0.767818  0.817025  0.799038  0.996065
# 314  0.704582  0.878207  0.822987  0.625625  0.476812  0.656297  0.799268
# 315  0.842290  0.829044  0.891115  0.708035  0.816047  0.658428  0.512517
# 316  0.849495  0.870318  0.953931  0.733893  0.738616  0.683191  0.921527
# 317  0.860511  0.894355  0.822057  0.721947  0.537042  0.631080  0.582066
# 318  0.869103  0.895748  0.914101  0.760505  0.668759  0.593463  0.912945
# 319  0.688608  0.786152  0.940425  0.655106  0.337482  0.667632  0.634304
# 320  0.838174  0.842947  0.918971  0.716628  0.818747  0.602325  0.909531
# 321  0.861548  0.854791  0.795494  0.599305  0.352214  0.439179  0.181614
# 322  0.803798  0.826579  0.983824  0.722341  0.914973  0.827840  0.998534
# 323  0.848701  0.769988  0.841933  0.683973  0.324478  0.460130  0.858221
# 324  0.789306  0.815318  0.893552  0.761301  0.905744  0.705830  0.991121
# 325  0.818482  0.751454  0.787402  0.712049  0.323556  0.592957  0.747725
# 326  0.783122  0.793302  0.861925  0.522971  0.246318  0.791820  0.858264
# 327  0.781751  0.799784  0.952932  0.765446  0.902613  0.679942  0.934335
# 328  0.804045  0.864232  0.935882  0.577356  0.901642  0.763943  0.989296
# 329  0.818254  0.837476  0.905849  0.746142  0.906276  0.700545  0.997498
# 330  0.814960  0.795891  0.969004  0.670227  0.946154  0.858806  0.999877
# 331  0.792402  0.838435  0.829637  0.552556  0.588534  0.596970  0.956568
# 332  0.798396  0.859251  0.879984  0.520813  0.784690  0.746481  0.991936
# 333  0.848606  0.833152  0.864269  0.685702  0.857775  0.809027  0.996097
# 334  0.828408  0.807718  0.770657  0.610513  0.892577  0.703968  0.953341
# 335  0.878905  0.840533  0.944232  0.732519  0.886299  0.743165  0.961148
# 336  0.861917  0.791511  0.969610  0.577228  0.905870  0.836386  0.995896
# 337  0.882961  0.821938  0.971850  0.688956  0.908370  0.825320  0.991973
# 338  0.801682  0.771062  0.971377  0.568968  0.931848  0.858804  0.998982
# 339  0.821045  0.849664  0.889749  0.750745  0.917907  0.774091  0.992796
# 340  0.770222  0.841147  0.703686  0.691817  0.716048  0.537849  0.953326
# 341  0.753592  0.752771  0.561253  0.577542  0.493643  0.435813  0.840307
# 342  0.798645  0.839875  0.794416  0.739711  0.660115  0.574834  0.983660
# 343  0.762030  0.829594  0.788927  0.703960  0.598457  0.473963  0.968798
# 344  0.795561  0.812523  0.875774  0.727070  0.466280  0.463456  0.974085
# 345  0.780201  0.809366  0.717097  0.667237  0.525949  0.467487  0.945336
# 346  0.798269  0.798015  0.823909  0.699642  0.812069  0.677503  0.813681
# 347  0.879097  0.870265  0.841701  0.743089  0.671006  0.553387  0.926805
# 348  0.768931  0.834619  0.885398  0.514532  0.765322  0.650348  0.995420
# 349  0.689736  0.635784  0.741497  0.429699  0.580646  0.661152  0.621881
# 350  0.810150  0.845594  0.948708  0.552261  0.693802  0.699368  0.997735
# 351  0.743843  0.747182  0.809536  0.447722  0.750203  0.553188  0.812591
# 352  0.675176  0.720559  0.560886  0.452227  0.424188  0.514870  0.256240
# 353  0.730986  0.708792  0.858215  0.442899  0.616908  0.679421  0.988146
# 354  0.754470  0.766215  0.878462  0.472603  0.566676  0.651186  0.982650
# 355  0.774173  0.813302  0.894907  0.476721  0.830950  0.697177  0.948790
# 356  0.881365  0.809938  0.755031  0.626178  0.453107  0.533021  0.974359
# 357  0.787602  0.616564  0.596316  0.553429  0.323470  0.477735  0.098622
# 358  0.800710  0.725568  0.695381  0.552032  0.290162  0.511669  0.037614
# 359  0.669584  0.399318  0.748110  0.525897  0.446637  0.568745  0.629908
# 360  0.819189  0.829379  0.692305  0.633527  0.307324  0.519294  0.206122
# 361  0.802018  0.704000  0.770079  0.517832  0.458503  0.504000  0.615301
# 362  0.799175  0.736254  0.554742  0.461733  0.320352  0.362989  0.375605
# 363  0.866277  0.808816  0.724835  0.573221  0.450563  0.553622  0.490071
# 364  0.818391  0.683702  0.289050  0.717463  0.136910  0.121270  0.326013
# 365  0.882255  0.754479  0.784186  0.699364  0.808329  0.732577  0.981299
# 366  0.892879  0.674781  0.803702  0.697687  0.327584  0.464714  0.967335
# 367  0.855594  0.769355  0.672632  0.567856  0.298928  0.507215  0.639871
# 368  0.890248  0.744118  0.796267  0.729499  0.598663  0.726228  0.935455
# 369  0.885934  0.660455  0.626982  0.658439  0.326912  0.587272  0.912288
# 370  0.890885  0.733998  0.702746  0.724221  0.443098  0.611033  0.940842
# 371  0.843436  0.654651  0.641695  0.430756  0.354740  0.561112  0.904727
# 372  0.841414  0.570295  0.699473  0.458023  0.453492  0.632163  0.881298
# 373  0.898775  0.628113  0.663611  0.684403  0.388266  0.443597  0.931385
# 374  0.854349  0.815888  0.865371  0.761675  0.769088  0.717499  0.982596
# 375  0.780551  0.829089  0.935109  0.745806  0.876202  0.699338  0.981576
# 376  0.857692  0.797164  0.881167  0.730710  0.886399  0.685993  0.985736
# 377  0.756711  0.780470  0.844280  0.492176  0.866996  0.676505  0.992254
# 378  0.813789  0.832158  0.738018  0.744490  0.536545  0.594110  0.956327
# 379  0.840366  0.821545  0.941332  0.754817  0.581608  0.784215  0.987129
# 380  0.874831  0.846867  0.967847  0.731761  0.822391  0.805223  0.998687
# 381  0.782937  0.808524  0.581800  0.488105  0.748945  0.449610  0.944530
# 382  0.774390  0.801737  0.850496  0.565709  0.862199  0.606556  0.961426
# 383  0.779932  0.703341  0.895430  0.682642  0.549809  0.484706  0.996323
# 384  0.779276  0.823132  0.668413  0.609206  0.517454  0.506139  0.902520
# 385  0.815374  0.786803  0.872926  0.744553  0.890194  0.727536  0.982762
# 386  0.828301  0.699152  0.740377  0.542005  0.752102  0.596184  0.943588
# 387  0.807927  0.821151  0.748705  0.707523  0.521670  0.502291  0.814207
# 388  0.663265  0.656803  0.782231  0.522875  0.389104  0.517573  0.854309
# 389  0.791669  0.860542  0.864490  0.745547  0.554667  0.533916  0.879068
# 390  0.685747  0.690289  0.673613  0.561326  0.668457  0.601691  0.925293
# 391  0.828632  0.381819  0.976378  0.532578  0.349354  0.734929  0.950161
# 392  0.570179  0.338735  0.903555  0.355066  0.231115  0.442136  0.748317
# 393  0.469374  0.316161  0.865717  0.383019  0.283885  0.419224  0.714114
# 394  0.583576  0.299519  0.928089  0.559482  0.245463  0.512278  0.603496
# 395  0.505337  0.241539  0.920815  0.382769  0.252359  0.652837  0.836590
# 396  0.530116  0.189256  0.849733  0.433879  0.124944  0.168636  0.733618
# 397  0.578483  0.215023  0.850172  0.385833  0.196490  0.489580  0.782022
# 398  0.490707  0.220581  0.944723  0.365670  0.306538  0.645588  0.733191
# 399  0.567171  0.266167  0.843472  0.437530  0.176361  0.401412  0.239131
# 400  0.795649  0.722476  0.638368  0.556167  0.263246  0.538383  0.966190
# 401  0.886243  0.787233  0.943026  0.504423  0.920619  0.871915  0.999371
# 402  0.880051  0.787391  0.950619  0.558088  0.882718  0.865361  0.988362
# 403  0.875925  0.820174  0.957993  0.621809  0.915861  0.879145  0.996327
# 404  0.855825  0.734109  0.954952  0.588324  0.895226  0.857243  0.997395
# 405  0.882211  0.770196  0.934383  0.507349  0.740179  0.833605  0.985523
# 406  0.903047  0.829033  0.961675  0.542070  0.785599  0.863917  0.993153
# 407  0.885071  0.716233  0.938990  0.532017  0.881602  0.852727  0.995633
# 408  0.895162  0.842941  0.940559  0.523574  0.916197  0.840215  0.995170
# 409  0.927661  0.895547  0.346650  0.499617  0.099994  0.184686  0.406303
# 410  0.896125  0.858471  0.913173  0.693545  0.796623  0.796202  0.988643
# 411  0.901456  0.831051  0.928121  0.562092  0.819286  0.742361  0.969188
# 412  0.889141  0.851800  0.905706  0.542043  0.807181  0.694347  0.948523
# 413  0.894213  0.869231  0.942522  0.659923  0.888949  0.826023  0.993524
# 414  0.816220  0.824163  0.655895  0.605426  0.834033  0.542456  0.985072
# 415  0.834746  0.885960  0.796201  0.572812  0.808049  0.586291  0.972832
# 416  0.900639  0.897808  0.924053  0.626511  0.852836  0.756507  0.991600
# 417  0.793869  0.837745  0.558992  0.575405  0.729387  0.651903  0.954158
# 418  0.853942  0.854023  0.844035  0.617786  0.805506  0.619092  0.971311
# 419  0.790226  0.687184  0.801016  0.381534  0.674962  0.667414  0.978339
# 420  0.832771  0.589595  0.434850  0.374572  0.297553  0.440829  0.747591
# 421  0.797877  0.591720  0.545756  0.373633  0.634805  0.412694  0.926595
# 422  0.813775  0.651270  0.828008  0.421900  0.747324  0.487996  0.968596
# 423  0.785423  0.621684  0.652966  0.357824  0.665490  0.459155  0.942941
# 424  0.793317  0.583096  0.614829  0.380039  0.458521  0.487988  0.815109
# 425  0.809973  0.641156  0.749186  0.417375  0.250520  0.432180  0.853045
#
#          AU12      AU14      AU15  ...  HNRdBACF_sma3nz  F1frequency_sma3nz  \
# 0    0.586847  0.821137  0.850114  ...        10.691274          1260.29150
# 1    0.987136  0.903269  0.857272  ...        16.094858          1314.41520
# 2    0.227042  0.618040  0.936768  ...        12.496406          1213.90030
# 3    0.699144  0.581035  0.809511  ...        12.490333           997.06270
# 4    0.925253  0.864570  0.783783  ...        10.899385          1045.01600
# 5    0.559944  0.765572  0.777215  ...         7.228373          1026.54400
# 6    0.847633  0.822175  0.831704  ...        11.664253          1296.79580
# 7    0.984996  0.896480  0.702121  ...        11.650617           833.02484
# 8    0.706119  0.654103  0.610441  ...        12.346309          1023.69460
# 9    0.859696  0.757504  0.759179  ...        10.749550          1374.79530
# 10   0.044513  0.385810  0.748091  ...         5.969450           825.64430
# 11   0.841789  0.792857  0.946773  ...        13.752396          1073.20630
# 12   0.300471  0.633722  0.945151  ...         8.976640          1055.96680
# 13   0.464719  0.816258  0.920282  ...         5.192165           904.66230
# 14   0.448783  0.722522  0.939429  ...         8.763601          1175.00880
# 15   0.352987  0.511680  0.882360  ...        10.189300          1067.01990
# 16   0.141898  0.467444  0.901497  ...        10.894268          1279.66050
# 17   0.624885  0.729468  0.914830  ...        10.059978          1249.21290
# 18   0.513213  0.665618  0.906381  ...         7.228647           644.41620
# 19   0.155291  0.503442  0.899499  ...         8.162799          1090.64420
# 20   0.458205  0.686998  0.747151  ...         7.040733          1138.19180
# 21   0.784159  0.666698  0.920203  ...        10.124294          1096.44300
# 22   0.233423  0.401678  0.877787  ...        11.642026          1168.29480
# 23   0.530098  0.613301  0.840230  ...        13.056720          1080.74450
# 24   0.481214  0.445022  0.908492  ...        12.720609          1256.81950
# 25   0.227692  0.332881  0.888623  ...        10.998635          1076.78850
# 26   0.782853  0.733838  0.927268  ...         8.940590          1349.03870
# 27   0.682997  0.608418  0.930656  ...        13.990918           935.72320
# 28   0.581153  0.413444  0.886949  ...        13.176217          1006.59375
# 29   0.329970  0.487590  0.857979  ...        12.447152          1084.81380
# 30   0.164681  0.731332  0.849020  ...         8.616522           957.87177
# 31   0.634156  0.846714  0.920922  ...        12.273663          1130.27860
# 32   0.188856  0.908477  0.852081  ...        12.011708          1192.26660
# 33   0.082314  0.224957  0.901572  ...        10.376945          1194.79750
# 34   0.098610  0.510479  0.949298  ...        10.245376          1189.57580
# 35   0.065664  0.280467  0.891218  ...        10.859134          1488.80270
# 36   0.048596  0.440845  0.939314  ...        10.238502          1189.66030
# 37   0.267539  0.523483  0.900673  ...        11.643364           860.72485
# 38   0.337132  0.413853  0.877028  ...         8.397161          1191.43660
# 39   0.021907  0.376263  0.769673  ...        13.122043          1217.02780
# 40   0.091216  0.335145  0.645497  ...        12.617312           926.89060
# 41   0.102925  0.543805  0.673939  ...         7.219284          1249.21250
# 42   0.243692  0.837629  0.904825  ...        11.382413          1274.53530
# 43   0.108184  0.502276  0.895308  ...         9.744889          1531.48930
# 44   0.418437  0.855155  0.824238  ...        11.665236          1046.45900
# 45   0.454637  0.789946  0.642444  ...        12.545127          1276.77920
# 46   0.658360  0.876823  0.811809  ...         9.260839          1099.21940
# 47   0.143610  0.546526  0.815668  ...         8.650234          1283.96010
# 48   0.058448  0.406970  0.692962  ...         8.967689          1205.73690
# 49   0.098790  0.866113  0.528098  ...         9.587110          1237.34450
# 50   0.448662  0.582421  0.673377  ...         8.401618          1152.16320
# 51   0.810789  0.583709  0.812211  ...         5.803923           909.54250
# 52   0.558265  0.762862  0.777504  ...         7.420441          1351.21150
# 53   0.681966  0.564941  0.847334  ...         5.794774          1302.33920
# 54   0.268634  0.547894  0.789075  ...         2.300331          1425.69520
# 55   0.536723  0.674317  0.920314  ...         8.408893          1423.63220
# 56   0.617079  0.714234  0.838719  ...         9.778792           997.85690
# 57   0.760198  0.668518  0.895338  ...         6.140729          1059.73240
# 58   0.679214  0.648636  0.873965  ...         7.973658           928.13983
# 59   0.304409  0.797383  0.781674  ...         5.430674           936.68475
# 60   0.179781  0.844358  0.673110  ...         9.656656          1048.01380
# 61   0.058480  0.484264  0.805269  ...         9.723184          1107.36220
# 62   0.044763  0.505044  0.814731  ...        12.194565          1246.01330
# 63   0.465469  0.790109  0.873461  ...         8.105102          1199.10110
# 64   0.138881  0.676741  0.817380  ...         9.345857          1102.39930
# 65   0.649309  0.869523  0.865591  ...        10.212440          1339.74350
# 66   0.101513  0.803610  0.744373  ...         9.364865          1100.35630
# 67   0.425202  0.763517  0.706535  ...        11.346065          1057.62590
# 68   0.121212  0.919020  0.488947  ...         8.798245          1023.30840
# 69   0.382511  0.629544  0.798912  ...        12.197118           972.69070
# 70   0.897919  0.839890  0.898191  ...         5.724436          1327.24940
# 71   0.396774  0.645153  0.814642  ...        15.003444          1110.44450
# 72   0.196494  0.570621  0.768075  ...        14.174886           969.21420
# 73   0.463832  0.640498  0.883696  ...        12.838450          1058.83650
# 74   0.887564  0.869268  0.887067  ...        12.794068          1212.33950
# 75   0.635180  0.770017  0.873074  ...        10.349050          1138.10340
# 76   0.692576  0.702006  0.865999  ...        11.047890           908.38837
# 77   0.090603  0.486431  0.695875  ...        13.142783           974.15530
# 78   0.925262  0.771423  0.831400  ...         6.499018          1229.03450
# 79   0.590575  0.667446  0.704403  ...        10.715850          1148.83920
# 80   0.864138  0.750221  0.888679  ...        16.724771          1137.11770
# 81   0.516838  0.730704  0.916096  ...        11.387424          1202.84860
# 82   0.531252  0.745600  0.888584  ...        11.109909           998.57830
# 83   0.944970  0.799304  0.899040  ...        10.018552          1122.25430
# 84   0.781662  0.791368  0.874069  ...         9.311519          1335.86980
# 85   0.812446  0.809621  0.936234  ...         9.544545           985.18677
# 86   0.591578  0.734527  0.928171  ...         8.412968          1281.37700
# 87   0.818898  0.845379  0.886233  ...         9.960856           948.58720
# 88   0.796272  0.809840  0.850738  ...         9.099690           668.34344
# 89   0.259221  0.620729  0.945720  ...         6.127617          1096.32080
# 90   0.957560  0.898189  0.928249  ...         6.194476          1317.16940
# 91   0.483639  0.624684  0.760903  ...        11.740087          1348.76820
# 92   0.773561  0.735889  0.794085  ...         6.415062          1261.41550
# 93   0.907788  0.775990  0.800527  ...         7.965611          1197.75040
# 94   0.743932  0.751674  0.827867  ...         8.059700           987.36400
# 95   0.828356  0.832274  0.886864  ...         0.000000          1359.29580
# 96   0.943100  0.834722  0.894499  ...        13.132558          1758.79770
# 97   0.941914  0.844227  0.877110  ...         8.355263          1171.14690
# 98   0.555411  0.637581  0.709174  ...         0.000000          1229.02010
# 99   0.856673  0.801772  0.953467  ...         7.706264           966.59110
# 100  0.708425  0.813662  0.938674  ...        10.501386          1437.08010
# 101  0.551628  0.830339  0.896594  ...         8.061456          1332.61540
# 102  0.633224  0.748798  0.925027  ...        10.324245          1165.68910
# 103  0.959354  0.858946  0.930942  ...        11.311759          1007.70220
# 104  0.808062  0.802862  0.858106  ...         8.670422          1334.74180
# 105  0.782879  0.745824  0.905293  ...        10.139291          1113.23960
# 106  0.693089  0.724765  0.914355  ...         9.588676          1301.35820
# 107  0.277464  0.540338  0.725889  ...         8.269599           936.84600
# 108  0.924908  0.863854  0.886642  ...         9.814105          1146.88340
# 109  0.808670  0.711634  0.924868  ...        12.578473          1049.01050
# 110  0.334894  0.633967  0.717528  ...         8.700989           825.31270
# 111  0.954059  0.881158  0.946379  ...         4.969570          1175.70350
# 112  0.639258  0.863813  0.862261  ...         9.832639          1382.52580
# 113  0.929902  0.771490  0.932962  ...        13.270557          1234.08070
# 114  0.723520  0.707735  0.939539  ...        12.608134          1295.00670
# 115  0.905347  0.764860  0.884209  ...         7.008735           945.43720
# 116  0.951533  0.812186  0.915759  ...         9.769336          1155.94840
# 117  0.869804  0.848115  0.923385  ...        12.240302          1261.93500
# 118  0.515767  0.480974  0.777217  ...         8.997306          1296.66630
# 119  0.488784  0.374732  0.659176  ...         9.426771          1121.84100
# 120  0.920879  0.755969  0.870536  ...         8.318818          1392.97690
# 121  0.692684  0.598937  0.733713  ...        10.562076          1303.10780
# 122  0.904035  0.656293  0.810398  ...        10.038954          1445.67190
# 123  0.868157  0.635576  0.882873  ...         6.689478           970.98560
# 124  0.611375  0.707098  0.781608  ...        11.150757          1277.89880
# 125  0.662844  0.791853  0.901096  ...        10.608283          1032.52990
# 126  0.870906  0.834772  0.781357  ...        11.706725          1176.85300
# 127  0.448235  0.762312  0.522652  ...        11.962512          1241.47700
# 128  0.418647  0.909328  0.954486  ...        14.415769          1277.88100
# 129  0.325549  0.878160  0.932653  ...         9.351744          1295.15840
# 130  0.120405  0.801303  0.916556  ...        10.029650          1111.81620
# 131  0.125685  0.825411  0.816047  ...         7.277840          1351.78320
# 132  0.661482  0.859831  0.913029  ...         8.437774           988.37060
# 133  0.101446  0.604045  0.929300  ...         8.791103           605.13196
# 134  0.062016  0.767380  0.709030  ...        13.503268          1134.31150
# 135  0.780596  0.733299  0.854265  ...        11.946751          1108.00340
# 136  0.049879  0.692704  0.706642  ...         9.327710          1126.14760
# 137  0.907741  0.673510  0.875951  ...        10.609833          1103.06740
# 138  0.225669  0.745277  0.877531  ...         7.634329           921.30510
# 139  0.416353  0.795354  0.685334  ...        10.691421           855.37520
# 140  0.364483  0.773582  0.860427  ...         9.724952          1111.65620
# 141  0.061950  0.656200  0.778598  ...        10.573820          1102.08440
# 142  0.051424  0.712328  0.809062  ...        12.646989          1198.95910
# 143  0.050299  0.683388  0.757828  ...        10.207603          1197.23440
# 144  0.358483  0.655814  0.563189  ...         8.568235           950.29850
# 145  0.931056  0.904779  0.970919  ...         9.447139          1124.60780
# 146  0.710942  0.872317  0.901150  ...         0.000000          1080.41740
# 147  0.682488  0.886857  0.906558  ...        10.848549          1434.41830
# 148  0.892561  0.903244  0.900806  ...        13.163072          1282.52970
# 149  0.938337  0.883354  0.865643  ...        12.082024          1036.26260
# 150  0.988679  0.913498  0.898902  ...         8.266381          1299.36980
# 151  0.860184  0.829985  0.876363  ...        15.733945          1105.91980
# 152  0.366597  0.877904  0.861605  ...        14.414460          1153.12720
# 153  0.696674  0.704718  0.608603  ...        13.412675           982.51850
# 154  0.942154  0.755803  0.862341  ...        11.376058          1224.90150
# 155  0.817082  0.868128  0.868897  ...         7.818832          1005.86190
# 156  0.589174  0.601366  0.844016  ...        11.957871          1355.77150
# 157  0.618338  0.858589  0.843571  ...         9.143770           928.50350
# 158  0.422038  0.639063  0.719050  ...        11.801673          1157.99460
# 159  0.888900  0.826117  0.756368  ...        11.665957          1050.67660
# 160  0.701407  0.582697  0.880479  ...         9.904777           914.25270
# 161  0.938895  0.869722  0.929416  ...        10.779035           979.86040
# 162  0.928217  0.834533  0.842744  ...         4.475122          1158.49270
# 163  0.069222  0.331124  0.737513  ...        13.711369          1143.95730
# 164  0.638394  0.750840  0.962305  ...        11.934024           959.47900
# 165  0.684022  0.645338  0.916495  ...        10.813065           980.94210
# 166  0.942899  0.857814  0.880477  ...        15.625842          1028.71700
# 167  0.953691  0.863054  0.938620  ...        14.149293           767.96075
# 168  0.717203  0.766412  0.887257  ...        14.104386          1060.42380
# 169  0.443068  0.879035  0.857815  ...        13.278613          1258.20510
# 170  0.910068  0.903877  0.891107  ...         9.265278           869.93750
# 171  0.226384  0.841809  0.915550  ...        12.164304          1266.24390
# 172  0.426278  0.746612  0.883009  ...         5.542593           984.49640
# 173  0.908680  0.863014  0.889560  ...        12.036777           984.10860
# 174  0.913523  0.649590  0.860854  ...         7.919170          1504.45700
# 175  0.920025  0.733654  0.753327  ...         7.714560          1309.94930
# 176  0.932284  0.892794  0.932048  ...         9.724921          1108.04500
# 177  0.906724  0.789425  0.924481  ...        10.644925           967.05634
# 178  0.215479  0.783746  0.885335  ...        10.918591          1062.78720
# 179  0.253031  0.737855  0.723733  ...         8.307438           893.32040
# 180  0.869207  0.847396  0.820612  ...         8.824285          1370.79190
# 181  0.075963  0.601872  0.896913  ...        12.633350           974.42010
# 182  0.278859  0.623569  0.940815  ...        12.616379          1224.23470
# 183  0.233703  0.473642  0.801150  ...         9.531167          1073.04060
# 184  0.084626  0.329605  0.797424  ...         8.898877          1026.68620
# 185  0.109084  0.429200  0.926731  ...        10.901204          1072.73330
# 186  0.089144  0.457335  0.787472  ...         0.000000          1054.58310
# 187  0.090977  0.455949  0.903160  ...         1.327872          1045.20150
# 188  0.118761  0.341136  0.943808  ...        12.439721          1014.15740
# ...
# 291          2749.13650                   -4.596745
# 292          1327.71880                   -9.146591
# 293          1425.45590                   -5.759258
# 294          3317.05660                   -5.012323
# 295          1718.40860                   -2.917836
# 296          1816.19870                   11.142062
# 297          3463.42110                   -3.187943
# 298          1659.43500                   -0.791629
# 299          2561.17110                   -1.054433
# 300          1257.76010                   18.890337
# 301          1928.01040                   19.775484
# 302          2773.10180                   18.095660
# 303          1194.34270                   15.735286
# 304          1583.76160                   17.440912
# 305          1432.25780                    7.600726
# 306          1198.55500                   -4.129821
# 307          1886.78360                    8.439108
# 308          1115.56800                    3.194619
# 309          1615.59560                    0.970650
# 310          1532.13610                   15.481602
# 311          2721.70140                  -11.163150
# 312           993.78754                   -5.459017
# 313          1854.59720                   -4.716437
# 314          1501.66250                   -7.258411
# 315          2856.99020                    2.914652
# 316          2361.60820                  -11.262979
# 317          1213.50200                  -13.557765
# 318          1918.80990                   -4.464022
# 319          2062.09200                   -8.606410
# 320          1656.36660                   -4.406703
# 321          1992.36610                    5.904043
# 322          1177.91980                    9.730207
# 323          1196.38830                   -6.673190
# 324          2088.88380                  -11.250512
# 325          1301.61540                  -10.552089
# 326          1363.81090                   -9.731645
# 327          1842.44350                   -6.497226
# 328          1682.52060                   -4.199682
# 329          1765.77330                  -13.642017
# 330          1095.16500                   -5.103680
# 331          2002.62400                  -10.941258
# 332          1287.14360                  -15.605515
# 333          1523.45450                   -3.129790
# 334          1348.23080                    7.088933
# 335          1457.82290                   -1.479633
# 336          1535.35510                   -0.527086
# 337          3128.62100                    6.570294
# 338          1432.50730                    2.914559
# 339          2585.90620                   -8.878490
# 340          1140.14260                   -5.234395
# 341          1036.63220                   -9.726732
# 342          1139.15660                  -22.589891
# 343           873.88605                 -201.000000
# 344          1054.25400                   -8.242937
# 345          1080.21960                  -29.962180
# 346           978.55080                  -19.333408
# 347           900.74860                  -20.685902
# 348           896.33124                   -6.022765
# 349          1044.47000                  -11.206737
# 350          1630.11460                   14.045419
# 351          1557.69480                    1.643014
# 352          2486.54300                    4.201343
# 353          1978.99770                  -14.529546
# 354          1465.62300                    6.377493
# 355          1707.77800                   -6.659786
# 356          1222.26220                   -9.555611
# 357          2438.01400                    2.574541
# 358          2950.45300                   -5.574480
# 359          1290.54360                   17.832306
# 360          1893.19180                   13.545278
# 361          1363.36900                   17.341272
# 362          2968.93240                    2.456527
# 363          1473.46620                   -9.494820
# 364          2480.55790                    7.246429
# 365          1271.86190                  -13.285897
# 366          1323.72130                  -13.892647
# 367          1532.57650                   -5.377146
# 368          1432.25290                    7.338679
# 369          1980.22510                  -17.197243
# 370          1230.30650                  -10.592911
# 371          1373.71970                  -14.682198
# 372          1737.46740                   16.934744
# 373          1849.06120                  -11.947952
# 374          2880.03980                   -4.031029
# 375          2259.83810                  -11.464316
# 376          1526.02870                    9.598630
# 377          1614.44630                    6.202801
# 378          1375.68980                   15.721486
# 379          1883.55180                  -11.333632
# 380          1239.12000                   -9.050483
# 381          1579.17050                  -13.715985
# 382          1890.67090                    0.982260
# 383          2420.49490                    2.014108
# 384          1564.90000                   -2.588812
# 385          1718.64990                   -5.989579
# 386          1039.11280                  -14.583904
# 387          2195.73320                  -25.793983
# 388          1180.39160                   -9.189488
# 389          2875.07300                    3.469200
# 390          1582.75720                   -1.580126
# 391          2108.97340                   13.680240
# 392           881.99493                  -13.192088
# 393          2701.62570                  -10.592699
# 394          2318.26780                    5.808722
# 395          1223.68130                  -16.475777
# 396          1539.80330                   13.933258
# 397          1792.64450                  -19.500488
# 398          1969.80270                   -4.985871
# 399          2022.79040                    1.477426
# 400          2643.08960                    4.461799
# 401          1768.69930                   -1.876792
# 402          1744.94890                   -3.752158
# 403          1491.23450                  -12.998501
# 404          2127.62040                  -10.497983
# 405          1218.23160                    2.238859
# 406          1539.25380                   -1.790239
# 407          1501.57730                    8.958821
# 408          1456.18950                   15.863824
# 409          1342.89640                   -3.756704
# 410          2476.27950                   -1.638498
# 411          1421.85950                  -11.882459
# 412          1123.72840                   -3.126512
# 413          1558.73010                    7.523584
# 414          1138.54260                  -17.687521
# 415          1321.80700                   -2.098533
# 416          1723.57070                    0.734820
# 417          1599.42770                   -8.910635
# 418          1257.96060                   -8.311972
# 419          2206.19560                  -14.450772
# 420          2679.14360                    0.968736
# 421          2935.36100                    8.490104
# 422          2166.55050                  -11.388743
# 423          1165.26620                   32.468560
# 424          2112.57000                   -8.584558
# 425          1611.57510                    6.953911
# 426          2621.74880                  -14.253882
# 427          2989.38060                  -12.295621
# 428          1724.70130                   -1.347399
# 429          1442.66940                   10.007955
# 430          2859.80200                   -7.538317
# 431          1586.59460                   -4.284902
# 432          1837.11580                  -18.577919
# 433          1375.25090                  -21.237085
# 434          1918.82620                  -13.487312
# 435          1507.67140                   -7.214532
# 436          1471.32780                  -16.060532
# 437          1366.81930                    6.409092
#
# [438 rows x 31 columns]
# 訓練データの正解ラベル数: 438
# テストデータの正解ラベル数: 100
# 0
#                                              filepath       filename  \
# 1   C:\Users\robotics\proj\Research\code\voice\voi...  ID37_20ms.csv
# 21  C:\Users\robotics\proj\Research\code\voice\voi...  ID57_20ms.csv
# 23  C:\Users\robotics\proj\Research\code\voice\voi...  ID59_20ms.csv
# 25  C:\Users\robotics\proj\Research\code\voice\voi...  ID61_20ms.csv
# 26  C:\Users\robotics\proj\Research\code\voice\voi...  ID62_20ms.csv
# 27  C:\Users\robotics\proj\Research\code\voice\voi...  ID63_20ms.csv
# 30  C:\Users\robotics\proj\Research\code\voice\voi...  ID66_20ms.csv
# 38  C:\Users\robotics\proj\Research\code\voice\voi...  ID74_20ms.csv
# 46  C:\Users\robotics\proj\Research\code\voice\voi...  ID82_20ms.csv
# 54  C:\Users\robotics\proj\Research\code\voice\voi...  ID90_20ms.csv
# 58  C:\Users\robotics\proj\Research\code\voice\voi...  ID94_20ms.csv
#
#                                              facepath           facename  \
# 1   C:\Users\robotics\proj\Research\output_filtere...  filtered_ID37.csv
# 21  C:\Users\robotics\proj\Research\output_filtere...  filtered_ID57.csv
# 23  C:\Users\robotics\proj\Research\output_filtere...  filtered_ID59.csv
# 25  C:\Users\robotics\proj\Research\output_filtere...  filtered_ID61.csv
# 26  C:\Users\robotics\proj\Research\output_filtere...  filtered_ID62.csv
# 27  C:\Users\robotics\proj\Research\output_filtere...  filtered_ID63.csv
# 30  C:\Users\robotics\proj\Research\output_filtere...  filtered_ID66.csv
# 38  C:\Users\robotics\proj\Research\output_filtere...  filtered_ID74.csv
# 46  C:\Users\robotics\proj\Research\output_filtere...  filtered_ID82.csv
# 54  C:\Users\robotics\proj\Research\output_filtere...  filtered_ID90.csv
# 58  C:\Users\robotics\proj\Research\output_filtere...  filtered_ID94.csv
#
#     Delirium  Prediction
# 1          0           0
# 21         1           1
# 23         0           0
# 25         0           0
# 26         0           1
# 27         1           1
# 30         0           1
# 38         1           1
# 46         1           1
# 54         1           1
# 58         1           0
#
#
# このFoldの正解率 (ファイル単位): 0.7273 (8/11 ファイル正解)
#
# 混同行列:
#        予測: 0  予測: 1
# 正解: 0      3      2
# 正解: 1      1      5
#
#
#                         Feature  Importance
# 16                         AU43    0.056075
# 0                          AU01    0.051931
# 4                          AU06    0.047613
# 7                          AU12    0.044537
# 14                         AU26    0.038983
# 2                          AU04    0.036833
# 17            spectralFlux_sma3    0.036255
# 3                          AU05    0.035402
# 8                          AU14    0.033516
# 15                         AU28    0.033476
# 1                          AU02    0.032725
# 6                          AU10    0.032699
# 21              HNRdBACF_sma3nz    0.031882
# 18  F0semitoneFrom27.5Hz_sma3nz    0.031474
# 11                         AU23    0.030104
# 12                         AU24    0.029851
# 27   F2amplitudeLogRelF0_sma3nz    0.029830
# 19           jitterLocal_sma3nz    0.028547
# 5                          AU09    0.028423
# 24   F1amplitudeLogRelF0_sma3nz    0.027882
# 30   F3amplitudeLogRelF0_sma3nz    0.027750
# 9                          AU15    0.027731
# 13                         AU25    0.027484
# 20        shimmerLocaldB_sma3nz    0.026555
# 10                         AU17    0.026014
# 22           F1frequency_sma3nz    0.025528
# 25           F2frequency_sma3nz    0.025384
# 23           F1bandwidth_sma3nz    0.025236
# 29           F3bandwidth_sma3nz    0.024430
# 28           F3frequency_sma3nz    0.024178
# 26           F2bandwidth_sma3nz    0.021674
# SHAP Values (全体) の形状: (438, 31, 2)
# SHAP Values (Class 1) の形状: (438, 31)
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# 間違えたファイルの (start, end) リスト: [(93, 100)]
# SHAP Values (error) の形状: (7, 31, 2)
# 5つのFoldのファイル単位での平均正解率：0.5288
#
# 5つのFoldのファイル単位での性能のばらつき(標準偏差)：0.1387

# %% [markdown]
# XGBoostに変更

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import os
#from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb
from sklearn.metrics import accuracy_score
from scipy.stats import mode
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import shap

pd.options.display.max_rows = None

folder_face_path = Path(r"C:\Users\robotics\proj\Research\output_filtered_questions")
face_files = list(folder_face_path.glob('*.csv'))
face_df = pd.DataFrame({'facepath': face_files})
face_df['facename'] = face_df['facepath'].apply(lambda p: Path(p).name)
#print(face_df)

# ファイルとdeliriumの結合
folder_path = Path(r"C:\Users\robotics\proj\Research\code\voice\voice_csv_20ms")
all_files = list(folder_path.glob('*.csv'))


df = pd.DataFrame({'filepath': all_files})
#print(df)

files_df = df 

#print(files_df)
files_df['filename'] = df['filepath'].apply(lambda p: Path(p).name)
files_df = pd.concat([files_df, face_df], axis=1)
#print(files_df)


files_df['ID'] = files_df['filename'].str.extract(r'ID(\d+)_')
files_df['ID'] = files_df['ID'].astype(int)
#print(files_df)

labels_df = pd.read_csv(r"C:\Users\robotics\proj\Research\code\voice\delirium.csv")
#print(labels_df)

file_with_labels_df = pd.merge(files_df, labels_df, on='ID', how='left')

file_with_labels_df.drop(columns=['ID', 'Sex'], inplace=True)
#print(file_with_labels_df)
#print(file_with_labels_df.columns)

#KFold Cross Validation
model = xgb.XGBClassifier(
    objective='binary:logistic',  # 目的関数: 2値分類
    eval_metric='logloss',        # 評価指標
    n_estimators=100,             # 木の数
    learning_rate=0.1,
    max_depth=3,
    use_label_encoder=False,      # 最近のバージョンで推奨
    random_state=42
)
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = []

#CSVファイルのデータ
X_files = file_with_labels_df
#print(X_files)
#せん妄の有無(0 or 1)
y_labels = file_with_labels_df['Delirium']
#print(y_labels[2])

for fold, (train_indices, test_indices) in enumerate(kf.split(X_files, y_labels)):

    train_files = X_files.iloc[train_indices]
    test_files = X_files.iloc[test_indices]
    #print(train_indices)
    #print(train_files)

    print(f"--- Fold {fold+1} ---")
    print(f"訓練ファイル数: {len(train_files)}, テストファイル数: {len(test_files)}")

    #print(test_files)
    #音声ファイルのパスを取得
    train_files_path = [folder_path / fname for fname in train_files['filename']]
    test_files_path = [folder_path / fname for fname in test_files['filename']]
    #表情ファイルのパスを取得
    face_train_path = [folder_face_path / fname for fname in train_files['facepath']]
    face_test_path = [folder_face_path / fname for fname in test_files['facepath']]

    #print(face_train_path)
    train_df = pd.DataFrame()
    test_df = pd.DataFrame()
    for v, f in zip(train_files_path, face_train_path):
        #df_train_file = pd.read_csv(f).iloc[::2]
        df_train_file = pd.read_csv(v)
        df_face_train_file = pd.read_csv(f)

        #print(df_face_train_file)
        #print(f)
        current_filename = os.path.basename(v)
        #print(current_filename)
        rows = train_files[train_files['filename'] == current_filename]
        #print(rows)
        file_delirium = rows['Delirium'].iloc[0]
        #print(file_delirium)
        df_train_file['Delirium'] = file_delirium
        df_train_file['filename'] = current_filename
        #print(df_train_file)

        #df_train_file['Delirium'] = train_files[train_files['filename'] == current_filename]['Delirium'].iloc[2]
        
        #delete space
        df_train_file['label'] = df_train_file['label'].str.strip()
        df_face_train_file['label'] = df_face_train_file['label'].astype(str).str.strip()

        #only answer1-10
        max_df1 = df_train_file[df_train_file["label"].str.match('^answer(10|[1-9])$', na=False)]

        max_df2 = df_face_train_file[df_face_train_file['label'].str.match('^answer(10|[1-9])$', na=False)]
        confidence_to_delete = max_df2['Confidence'] <= 0.90
        rows_to_delete = max_df2[confidence_to_delete].index
        new_max_df2 = max_df2.drop(rows_to_delete)
        columns_to_extract = ["label"] + [col for col in new_max_df2.columns if col.startswith("AU")]
        new_max_df2 = new_max_df2[columns_to_extract]
        
        
        max_df1_file = max_df1.dropna()
        #max_df2_file = new_max_df2.dropna()

        columns_to_convert = ['start', 'end', 'original_start', 'original_end', 'filename']

        # forループを使って、指定した列を順番に数値型に変換
        for col in columns_to_convert:
            max_df1_file[col] = pd.to_numeric(max_df1_file[col], errors='coerce')

        #max_df1_file.info()

        max_df_train_file = max_df1_file.groupby('label').max()
        max_face_train_file = new_max_df2.groupby('label').max()
        #print(max_df_train_file)

        max_df_train_file = max_df_train_file.reset_index(drop=True)
        max_face_train_file = max_face_train_file.reset_index(drop=True)
        #print(max_df_train_file)
        max_multimodal_train_file = pd.concat([max_face_train_file, max_df_train_file], axis=1)

        train_df = pd.concat([train_df, max_multimodal_train_file], ignore_index=True)

        #print(train_df)
    #train_df.to_csv('output.csv', index=False, encoding='utf-8-sig')
    test_file_lengths = []
    for v, f in zip(test_files_path, face_test_path):
        #df_test_file = pd.read_csv(f).iloc[::2]
        df_test_file = pd.read_csv(v)
        df_face_test_file = pd.read_csv(f)

        #print(f)
        current_filename = os.path.basename(v)

        #print(current_filename)
        rows = test_files[test_files['filename'] == current_filename]
        #print(rows)
        file_delirium = rows['Delirium'].iloc[0]
        #print(file_delirium)
        df_test_file['Delirium'] = file_delirium
        df_test_file['filename'] = current_filename

        #delete space
        df_test_file['label'] = df_test_file['label'].str.strip()
        df_face_test_file['label'] = df_face_test_file['label'].astype(str).str.strip()
        #only answer1-10
        max_df3 = df_test_file[df_test_file["label"].str.match('^answer(10|[1-9])$', na=False)]
        #face
        max_df4 = df_face_test_file[df_face_test_file['label'].str.match('^answer(10|[1-9])$', na=False)]
        confidence_to_delete = max_df4['Confidence'] <= 0.90
        rows_to_delete = max_df4[confidence_to_delete].index
        new_max_df4 = max_df4.drop(rows_to_delete)
        columns_to_extract = ["label"] + [col for col in new_max_df4.columns if col.startswith("AU")]
        new_max_df4 = new_max_df4[columns_to_extract]

        max_df3_file = max_df3.dropna()
        #max_df4_file = new_max_df4.dropna()

        columns_to_convert = ['start', 'end', 'original_start', 'original_end', 'filename']

        # forループを使って、指定した列を順番に数値型に変換
        for col in columns_to_convert:
            max_df3_file[col] = pd.to_numeric(max_df3_file[col], errors='coerce')

        max_df_test_file = max_df3_file.groupby('label').max()
        max_face_test_file = new_max_df4.groupby('label').max()

        max_df_test_file = max_df_test_file.reset_index(drop=True)
        max_face_test_file = max_face_test_file.reset_index(drop=True)

        max_multimodal_test_file = pd.concat([max_face_test_file, max_df_test_file], axis=1)

        test_file_lengths.append(len(max_df_test_file))

        test_df = pd.concat([test_df, max_multimodal_test_file], ignore_index=True)
    #test_df.to_csv('output.csv', index=False, encoding='utf-8-sig')
    #print(train_df)
    #print(test_df)


    #train_df = pd.concat([pd.read_csv(f).iloc[::2] for f in train_files_path], ignore_index=True)
    #test_df = pd.concat([pd.read_csv(f).iloc[::2] for f in test_files_path], ignore_index=True)

    #train_df = pd.concat([pd.read_csv(f) for f in train_files_path], ignore_index=True)
    #test_df = pd.concat([pd.read_csv(f) for f in test_files_path], ignore_index=True)
    #print(train_df)
    #print(test_df)

    print(f"訓練データ行数: {len(train_df)}")
    #train_df = train_df.iloc[::2]
    #train_df = train_df.reset_index(drop=True)
    #print(f"間引き後の訓練データ行数: {len(train_df)}")

    print(f"テストデータ行数: {len(test_df)}")
    #test_df = test_df.iloc[::2]
    #test_df = test_df.reset_index(drop=True)
    #print(f"間引き後の訓練データ行数: {len(test_df)}")


    columns_drop = ['start', 'end', 'label', 'alphaRatio_sma3', 'hammarbergIndex_sma3', 'slope0-500_sma3', 'slope500-1500_sma3', 'mfcc1_sma3', 'mfcc2_sma3', 'mfcc3_sma3', 'mfcc4_sma3','Loudness_sma3', 'logRelF0-H1-H2_sma3nz', 'logRelF0-H1-A3_sma3nz', 'original_start', 'original_end', 'Delirium', 'filename', 'AU07', 'AU11', 'AU20']
    #'Loudness_sma3'

    #print(train_indices)
    #print(test_indices)

    #y_train = y_labels.iloc[train_indices].repeat([len(pd.read_csv(f)) for f in train_files_path])
    #y_test = y_labels.iloc[test_indices].repeat([len(pd.read_csv(f)) for f in test_files_path])
    #print(y_train)

    #print(f"元の訓練データ行数: {len(y_train)}")
    #y_train = y_train.iloc[::2]
    #y_train = y_train.reset_index(drop=True)
    #print(f"間引き後の訓練データ行数: {len(y_train)}")

    #print(f"元のテストデータ行数: {len(y_test)}")
    #y_test = y_test.iloc[::2]
    #y_test = y_test.reset_index(drop=True)
    #print(f"間引き後のテストデータ行数: {len(y_test)}")

    y_train = train_df['Delirium']
    #print(y_train)
    y_test = test_df['Delirium']
    #print(y_test)
    X_train = train_df.drop(columns=columns_drop, errors='ignore')
    X_test = test_df.drop(columns=columns_drop, errors='ignore')
    
    #print(X_train.columns)

    print(f"訓練データの正解ラベル数: {len(y_train)}")
    print(f"テストデータの正解ラベル数: {len(y_test)}")

    #print(X_train)

    #NaNの数をカウント
    print(y_train.isnull().sum())

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_true = y_test
    #print(y_pred)

    file_predictions = []

    # 各テストファイルの行数を事前に計算しておく

    #test_file_lengths = [len(pd.read_csv(f).iloc[::2]) for f in test_files_path]
    #print(test_file_lengths)

    start_idx = 0
    for length in test_file_lengths:
        end_idx = start_idx + length
        #print(start_idx, end_idx)
        predictions_for_this_file = y_pred[start_idx:end_idx]
        #print(predictions_for_this_file)
        majority_vote = mode(predictions_for_this_file)[0]
        #print(majority_vote)
        file_predictions.append([majority_vote, start_idx, end_idx])
        start_idx = end_idx

    first_column_list = [item[0] for item in file_predictions]

    #print(file_predictions)

    y_test_files = test_files['Delirium'].values

    #print(y_test_files)

    test_files_copy = test_files
    #test_files_copy['Predict'] = file_predictions
    test_files_copy = test_files_copy.assign(Prediction=first_column_list)

    print(test_files_copy)

    correct_files = np.sum(np.array(first_column_list) == y_test_files)
    total_files = len(test_files)
    accuracy = correct_files/ total_files

    scores.append(accuracy)
    print("\n")
    print(f"このFoldの正解率 (ファイル単位): {accuracy:.4f} ({correct_files}/{total_files} ファイル正解)\n")

    # 4-2. 混同行列の計算
    # y_test_files (正解ラベル) と file_predictions (予測ラベル) を渡す
    cm = confusion_matrix(y_test_files, first_column_list)

    # 4-3. 見やすいようにDataFrameに変換して表示
    # ラベルが0と1の場合
    cm_df = pd.DataFrame(cm, 
                     index=['正解: 0', '正解: 1'], 
                     columns=['予測: 0', '予測: 1'])

    print("混同行列:")
    print(cm_df)
    print("\n") # 見やすいように改行

    #特徴量の重要度を取得
    #feature_names = X_train.columns.tolist()
    
    #mportances = model.feature_importances_

    #特徴量の名前と重要度をまとめたDataFrameを作成
    #importance_df = pd.DataFrame({
        #'Feature': feature_names,
        #'Importance': importances
    #})

    #重要度が高い順にソート
    #sorted_importance_df = importance_df.sort_values(by='Importance', ascending=False)

    #print(sorted_importance_df)

    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X_train) 

    #shap_values 全体の形状を確認 (おそらく (479, 14, 2))
    print(f"SHAP Values (全体) の形状: {shap_values.shape}")

    #せん妄ありのSHAP値だけをスライス ---
    shap_values_class1 = shap_values

    #スライスした後の形状を確認 (これで (479, 14) になるはず)
    print(f"SHAP Values (Class 1) の形状: {shap_values_class1.shape}")
    #print(f"X_train の形状: {X_train.shape}")

    #スライスした shap_values_class1 を渡す
    shap.summary_plot(shap_values_class1, X_train)

    #予測が0で正解が1の場合
    shap.initjs()

    misclassified_indices = []

    for pred, true_label, full_item in zip(first_column_list, y_test_files, file_predictions):

        if (pred == 0) & (true_label == 1):
            start_idx = full_item[1]
            end_idx = full_item[2]

            misclassified_indices.append((start_idx, end_idx))

    print(f"間違えたファイルの (start, end) リスト: {misclassified_indices}")

    #間違えたセグメントを格納するための空のリスト
    X_test_errors_list = []

    for start, end in misclassified_indices:
        #X_test から start から end までのセグメントをスライス
        #(iloc は X_test がDataFrameの場合。Numpy配列なら X_test[start:end] )
        segment = X_test.iloc[start:end] 
        X_test_errors_list.append(segment)

    #抜き出したセグメントをすべて結合
    if X_test_errors_list:
        X_test_errors = pd.concat(X_test_errors_list) #DataFrameの場合
        
        #これで初めて X_test_errors に対して SHAP が実行できる
        shap_values_errors = explainer.shap_values(X_test_errors)
        
        print(f"SHAP Values (error) の形状: {shap_values_errors.shape}")
        shap.summary_plot(shap_values_errors, X_test_errors)
    else:
        print("該当するエラーはありませんでした。")

    #特徴量ごとの散布図を比較
    #feature_name = 'Loudness_sma3'

    #fig, (sp1, sp2) = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
    #fig.suptitle(f'{feature_name}', fontsize=16)

    #sp1.scatter(range(len(X_train)), X_train[feature_name], alpha=0.6)
    #sp1.set_title('train data')
    #sp1.set_xlabel('index')
    #sp1.set_ylabel(feature_name)
    #sp1.grid(True)

    #sp2.scatter(range(len(X_test)), X_test[feature_name], alpha=0.6)
    #sp2.set_title('test data')
    #sp2.set_xlabel('index')
    #sp2.set_ylabel(feature_name)
    #sp2.grid(True)

    #グラフを表示
    #plt.tight_layout(rect=[0, 0.03, 1, 0.95])a
    #plt.show()

    

total_accuracy = sum(scores) / len(scores)
print(f"5つのFoldのファイル単位での平均正解率：{total_accuracy:.4f}\n")
print(f"5つのFoldのファイル単位での性能のばらつき(標準偏差)：{np.std(scores):.4f}")
# Out:
# --- Fold 1 ---
# 訓練ファイル数: 47, テストファイル数: 12
# 訓練データ行数: 426
# テストデータ行数: 112
# 訓練データの正解ラベル数: 426
# テストデータの正解ラベル数: 112
# 0
#                                              filepath  ... Prediction
# 4   C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 7   C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 8   C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 15  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 16  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 17  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 19  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 24  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 35  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 36  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 43  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 44  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
#
# [12 rows x 6 columns]
#
#
# このFoldの正解率 (ファイル単位): 0.5000 (6/12 ファイル正解)
#
# 混同行列:
#        予測: 0  予測: 1
# 正解: 0      3      3
# 正解: 1      3      3
#
#
# SHAP Values (全体) の形状: (426, 31)
# SHAP Values (Class 1) の形状: (426, 31)
# c:\Users\robotics\proj\delirium\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:09:43] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# 間違えたファイルの (start, end) リスト: [(10, 20), (20, 29), (93, 102)]
# SHAP Values (error) の形状: (28, 31)
# --- Fold 2 ---
# 訓練ファイル数: 47, テストファイル数: 12
# 訓練データ行数: 426
# テストデータ行数: 112
# 訓練データの正解ラベル数: 426
# テストデータの正解ラベル数: 112
# 0
#                                              filepath  ... Prediction
# 0   C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 2   C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 11  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 20  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 29  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 32  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 37  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 39  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 42  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 51  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 53  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 57  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
#
# [12 rows x 6 columns]
#
#
# このFoldの正解率 (ファイル単位): 0.3333 (4/12 ファイル正解)
#
# 混同行列:
#        予測: 0  予測: 1
# 正解: 0      1      5
# 正解: 1      3      3
#
#
# SHAP Values (全体) の形状: (426, 31)
# SHAP Values (Class 1) の形状: (426, 31)
# c:\Users\robotics\proj\delirium\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:09:58] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# 間違えたファイルの (start, end) リスト: [(30, 39), (67, 76), (102, 112)]
# SHAP Values (error) の形状: (28, 31)
# --- Fold 3 ---
# 訓練ファイル数: 47, テストファイル数: 12
# 訓練データ行数: 429
# テストデータ行数: 109
# 訓練データの正解ラベル数: 429
# テストデータの正解ラベル数: 109
# 0
#                                              filepath  ... Prediction
# 5   C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 6   C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 12  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 13  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 14  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 22  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 33  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 40  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 41  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 49  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 50  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 55  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
#
# [12 rows x 6 columns]
#
#
# このFoldの正解率 (ファイル単位): 0.8333 (10/12 ファイル正解)
#
# 混同行列:
#        予測: 0  予測: 1
# 正解: 0      5      1
# 正解: 1      1      5
#
#
# SHAP Values (全体) の形状: (429, 31)
# SHAP Values (Class 1) の形状: (429, 31)
# c:\Users\robotics\proj\delirium\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:10:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# 間違えたファイルの (start, end) リスト: [(92, 100)]
# SHAP Values (error) の形状: (8, 31)
# --- Fold 4 ---
# 訓練ファイル数: 47, テストファイル数: 12
# 訓練データ行数: 433
# テストデータ行数: 105
# 訓練データの正解ラベル数: 433
# テストデータの正解ラベル数: 105
# 0
#                                              filepath  ... Prediction
# 3   C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 9   C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 10  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 18  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 28  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 31  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 34  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 45  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 47  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 48  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 52  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 56  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
#
# [12 rows x 6 columns]
#
#
# このFoldの正解率 (ファイル単位): 0.2500 (3/12 ファイル正解)
#
# 混同行列:
#        予測: 0  予測: 1
# 正解: 0      1      4
# 正解: 1      5      2
#
#
# SHAP Values (全体) の形状: (433, 31)
# SHAP Values (Class 1) の形状: (433, 31)
# c:\Users\robotics\proj\delirium\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:10:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# 間違えたファイルの (start, end) リスト: [(29, 37), (51, 61), (69, 77), (77, 86), (96, 105)]
# SHAP Values (error) の形状: (44, 31)
# --- Fold 5 ---
# 訓練ファイル数: 48, テストファイル数: 11
# 訓練データ行数: 438
# テストデータ行数: 100
# 訓練データの正解ラベル数: 438
# テストデータの正解ラベル数: 100
# 0
#                                              filepath  ... Prediction
# 1   C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 21  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 23  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 25  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
# 26  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 27  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 30  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 38  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 46  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 54  C:\Users\robotics\proj\Research\code\voice\voi...  ...          1
# 58  C:\Users\robotics\proj\Research\code\voice\voi...  ...          0
#
# [11 rows x 6 columns]
#
#
# このFoldの正解率 (ファイル単位): 0.7273 (8/11 ファイル正解)
#
# 混同行列:
#        予測: 0  予測: 1
# 正解: 0      3      2
# 正解: 1      1      5
#
#
# SHAP Values (全体) の形状: (438, 31)
# SHAP Values (Class 1) の形状: (438, 31)
# c:\Users\robotics\proj\delirium\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:10:41] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# 間違えたファイルの (start, end) リスト: [(93, 100)]
# SHAP Values (error) の形状: (7, 31)
# 5つのFoldのファイル単位での平均正解率：0.5288
#
# 5つのFoldのファイル単位での性能のばらつき(標準偏差)：0.2231

# %%
import pathlib as Path
from pathlib import Path
import numpy as np
import pandas as pd
import os

folder_face_path = Path(r'C:\Users\robotics\proj\Research\output_filtered_questions')
face_files = list(folder_face_path.glob('*.csv'))

folder_voice_path = Path(r'C:\Users\robotics\proj\Research\code\voice\voice_csv_20ms')
voice_files = list(folder_voice_path.glob('*.csv'))

#print(face_files)

for f, v in zip(face_files, voice_files):
    face = pd.read_csv(f)
    voice = pd.read_csv(v)

    face_current_filename = os.path.basename(f)
    voice_current_filename = os.path.basename(v)

    face['label'] = face['label'].str.strip()
    face_answer = face[face["label"].str.match('^answer(10|[1-9])$', na=False)]

    face_answer_drop = face_answer.dropna()

    face_max = face_answer_drop.groupby('label').max()
    face_max = face_max.reset_index()

    voice['label'] = voice['label'].str.strip()
    voice_answer = voice[voice["label"].str.match('^answer(10|[1-9])$', na=False)]

    voice_answer_drop = voice_answer.dropna()

    voice_max = voice_answer_drop.groupby('label').max()
    voice_max = voice_max.reset_index()
    
    print(face_current_filename, voice_current_filename)
    #print("\n")
    print(len(face_max), len(voice_max))
# Out:
# filtered_ID30.csv ID30_20ms.csv
# 10 10
# filtered_ID31.csv ID31_20ms.csv
# 10 10
# filtered_ID32.csv ID32_20ms.csv
# 10 10
# filtered_ID33.csv ID33_20ms.csv
# 10 10
# filtered_ID34.csv ID34_20ms.csv
# 8 8
# filtered_ID35.csv ID35_20ms.csv
# 9 9
# filtered_ID36.csv ID36_20ms.csv
# 10 10
# filtered_ID37.csv ID37_20ms.csv
# 10 10
# filtered_ID38.csv ID38_20ms.csv
# 10 10
# filtered_ID39.csv ID39_20ms.csv
# 10 10
# filtered_ID40.csv ID40_20ms.csv
# 10 10
# filtered_ID41.csv ID41_20ms.csv
# 10 10
# filtered_ID42.csv ID42_20ms.csv
# 10 10
# filtered_ID43.csv ID43_20ms.csv
# 10 10
# filtered_ID44.csv ID44_20ms.csv
# 9 9
# filtered_ID45.csv ID45_20ms.csv
# 9 9
# filtered_ID46.csv ID46_20ms.csv
# 10 10
# filtered_ID47.csv ID47_20ms.csv
# 10 10
# filtered_ID48.csv ID48_20ms.csv
# 10 10
# filtered_ID49.csv ID49_20ms.csv
# 8 8
# filtered_ID50.csv ID50_20ms.csv
# 10 10
# filtered_ID51.csv ID51_20ms.csv
# 9 9
# filtered_ID52.csv ID52_20ms.csv
# 9 9
# filtered_ID53.csv ID53_20ms.csv
# 8 8
# filtered_ID54.csv ID54_20ms.csv
# 8 8
# filtered_ID55.csv ID55_20ms.csv
# 10 10
# filtered_ID56.csv ID56_20ms.csv
# 9 9
# filtered_ID57.csv ID57_20ms.csv
# 10 10
# filtered_ID58.csv ID58_20ms.csv
# 9 9
# filtered_ID59.csv ID59_20ms.csv
# 10 10
# filtered_ID60.csv ID60_20ms.csv
# 10 10
# filtered_ID61.csv ID61_20ms.csv
# 9 9
# filtered_ID62.csv ID62_20ms.csv
# 9 9
# filtered_ID63.csv ID63_20ms.csv
# 9 9
# filtered_ID64.csv ID64_20ms.csv
# 9 9
# filtered_ID65.csv ID65_20ms.csv
# 10 10
# filtered_ID66.csv ID66_20ms.csv
# 9 9
# filtered_ID67.csv ID67_20ms.csv
# 5 5
# filtered_ID68.csv ID68_20ms.csv
# 8 8
# filtered_ID69.csv ID69_20ms.csv
# 9 9
# filtered_ID70.csv ID70_20ms.csv
# 10 10
# filtered_ID71.csv ID71_20ms.csv
# 10 10
# filtered_ID72.csv ID72_20ms.csv
# 8 8
# filtered_ID73.csv ID73_20ms.csv
# 10 10
# filtered_ID74.csv ID74_20ms.csv
# 9 9
# filtered_ID75.csv ID75_20ms.csv
# 9 9
# filtered_ID76.csv ID76_20ms.csv
# 9 9
# filtered_ID77.csv ID77_20ms.csv
# 8 8
# filtered_ID78.csv ID78_20ms.csv
# 10 10
# filtered_ID79.csv ID79_20ms.csv
# 9 9
# filtered_ID80.csv ID80_20ms.csv
# 10 10
# filtered_ID81.csv ID81_20ms.csv
# 8 8
# filtered_ID82.csv ID82_20ms.csv
# 9 9
# filtered_ID83.csv ID83_20ms.csv
# 8 8
# filtered_ID84.csv ID84_20ms.csv
# 9 9
# filtered_ID85.csv ID85_20ms.csv
# 9 9
# filtered_ID86.csv ID86_20ms.csv
# 8 8
# filtered_ID87.csv ID87_20ms.csv
# 8 8
# filtered_ID88.csv ID88_20ms.csv
# 10 10
# filtered_ID89.csv ID89_20ms.csv
# 8 8
# filtered_ID90.csv ID90_20ms.csv
# 9 9
# filtered_ID91.csv ID91_20ms.csv
# 9 9
# filtered_ID92.csv ID92_20ms.csv
# 9 9
# filtered_ID93.csv ID93_20ms.csv
# 10 10
# filtered_ID94.csv ID94_20ms.csv
# 7 7
